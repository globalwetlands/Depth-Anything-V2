# %%
import os
import numpy as np
import pandas as pd
import cv2
from pycocotools.coco import COCO
from pycocotools import mask as maskUtils

# Define directories
image_directory = '../data/deigo/annotate-frames'  # Original Images
depth_map_directory = '../data/deigo/depth-maps/stingray-vid/'  # Depth Map Images
json_file = '../data/deigo/diego-pipe-annotations/annotations/instances_default.json'  # JSON file

# Path to save results
results_csv_path = '../data/deigo/results_stingray_vid.csv'

# Images and their corresponding annotations
image_names = [
    'stingray_frame_000001.png',
    'stingray_frame_000002.png',
    'stingray_frame_000003.png'
]

# Load the COCO annotations
coco = COCO(json_file)

# Create a mapping from category_id to category_name
cats = coco.loadCats(coco.getCatIds())
category_mapping = {cat['id']: cat['name'] for cat in cats}
print("Category mapping:")
print(category_mapping)

def load_and_normalize_depth_map(depth_map_path):
    # Load the depth map image
    depth_map = cv2.imread(depth_map_path, cv2.IMREAD_UNCHANGED)
    if depth_map is None:
        print(f"Failed to load depth map at {depth_map_path}.")
        return None

    # Normalize the depth map based on its data type
    if depth_map.dtype == np.uint8:
        # 8-bit depth map
        depth_map_normalized = depth_map / 255.0
    elif depth_map.dtype == np.uint16:
        # 16-bit depth map
        depth_map_normalized = depth_map / 65535.0
    else:
        # If depth map is already in float format between 0 and 1
        depth_map_normalized = depth_map

    return depth_map_normalized

def create_mask_from_annotation(ann, img_height, img_width):
    segmentation = ann['segmentation']

    if isinstance(segmentation, list):  # Polygon format
        mask = np.zeros((img_height, img_width), dtype=np.uint8)
        # Convert polygons to a mask
        for poly in segmentation:
            poly = np.array(poly).reshape((-1, 2))  # Reshape to (N, 2)
            cv2.fillPoly(mask, [np.int32(poly)], 1)  # Fill the polygon with 1's

    elif isinstance(segmentation, dict) and 'counts' in segmentation:  # RLE format
        rle = segmentation
        if isinstance(rle['counts'], list):  # Uncompressed RLE
            rle = maskUtils.frPyObjects([rle], img_height, img_width)
        mask = maskUtils.decode(rle)  # Decode RLE to binary mask

    else:
        mask = None  # Segmentation format not recognized

    return mask

# Load annotations for each image
annotations_dict = {}
image_sizes = {}

# Load all images and create a mapping from file_name to image ID
all_images = coco.loadImgs(coco.getImgIds())
file_name_to_id = {img['file_name']: img['id'] for img in all_images}

for img_name_with_ext in image_names:
    img_id = file_name_to_id.get(img_name_with_ext)
    if img_id is None:
        print(f"Image {img_name_with_ext} not found in annotations.")
        continue
    img_info = coco.loadImgs(img_id)[0]
    img_height = img_info['height']
    img_width = img_info['width']
    image_sizes[img_name_with_ext] = (img_width, img_height)
    ann_ids = coco.getAnnIds(imgIds=[img_id])
    anns = coco.loadAnns(ann_ids)
    annotations_dict[img_name_with_ext] = anns

print(f"Loaded annotations for images: {image_names}")

# Get and sort depth maps
depth_map_files = [f for f in os.listdir(depth_map_directory) if f.endswith('_pred04.png')]
depth_map_files.sort()  # Sort files to ensure correct order

num_depth_maps = len(depth_map_files)
print(f"Total number of depth maps: {num_depth_maps}")

# Calculate indices for dividing into thirds
third = num_depth_maps // 3
remainder = num_depth_maps % 3

indices = [
    (0, third),
    (third, 2 * third),
    (2 * third, 3 * third + remainder)
]

# Map each depth map to the corresponding image's annotations
results = []

for idx, (start_idx, end_idx) in enumerate(indices):
    img_name_with_ext = image_names[idx]
    if img_name_with_ext not in annotations_dict:
        print(f"No annotations found for image {img_name_with_ext}. Skipping this set of depth maps.")
        continue
    anns = annotations_dict[img_name_with_ext]
    img_width, img_height = image_sizes[img_name_with_ext]

    depth_maps_subset = depth_map_files[start_idx:end_idx]
    print(f"\nProcessing depth maps {start_idx} to {end_idx - 1} using annotations from {img_name_with_ext}")

    for depth_map_file in depth_maps_subset:
        depth_map_path = os.path.join(depth_map_directory, depth_map_file)
        depth_map = load_and_normalize_depth_map(depth_map_path)
        if depth_map is None:
            continue  # Skip if depth map couldn't be loaded

        depth_map_file_name = os.path.basename(depth_map_file)
        print(f"Processing depth map: {depth_map_file_name}")

        # Process each annotation
        for ann in anns:
            annotation_id = ann['id']
            category_id = ann['category_id']
            category_name = category_mapping.get(category_id, "Unknown")
            print(f"Processing annotation ID {annotation_id}, category ID {category_id}, category name {category_name}")

            # Create mask for the annotation
            mask = create_mask_from_annotation(ann, img_height, img_width)
            if mask is None:
                print(f"Failed to create mask for annotation {annotation_id}")
                continue  # Skip if mask couldn't be created

            # Resize depth map if necessary
            if depth_map.shape != mask.shape:
                depth_map_resized = cv2.resize(depth_map, (img_width, img_height), interpolation=cv2.INTER_NEAREST)
            else:
                depth_map_resized = depth_map

            # Apply the mask to the depth map to extract depth values
            depth_values = depth_map_resized[mask == 1]
            mean_depth = depth_values.mean() if depth_values.size > 0 else 0
            normalized_depth = mean_depth  # Depth map is already normalized between 0 and 1

            # Convert normalized depth to metric depth
            zmin = 0.4  # Minimum depth in meters (adjust if necessary)
            zmax = 20.0  # Maximum depth in meters (adjust if necessary)
            value_metric = (normalized_depth * (zmax - zmin)) + zmin

            print(f"Annotation ID {annotation_id}: mean depth {mean_depth}, normalized depth {normalized_depth}, value_metric {value_metric}")

            # Append the result to the list
            results.append({
                'depth_map_file': depth_map_file_name,
                'annotation_image': img_name_with_ext,
                'annotation_id': annotation_id,
                'category_id': category_id,
                'category_name': category_name,
                'normalized_depth': normalized_depth,
                'z-min': zmin,
                'z-max': zmax,
                'value_metric': value_metric
            })

# Create a DataFrame from the results
results_df = pd.DataFrame(results)

# Display the DataFrame
print("\nResults DataFrame:")
print(results_df.head())

# Save the results to a CSV file
results_df.to_csv(results_csv_path, index=False)
print(f"\nResults saved to {results_csv_path}")
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Category mapping:
# {1: '50', 2: '60', 3: '70', 4: '80', 5: '90'}
# Loaded annotations for images: ['stingray_frame_000001.png', 'stingray_frame_000002.png', 'stingray_frame_000003.png']
# Total number of depth maps: 185
#
# Processing depth maps 0 to 60 using annotations from stingray_frame_000001.png
# Processing depth map: stingray_frame_000001_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8066136663482099, normalized depth 0.8066136663482099, value_metric 16.209627860424913
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8330031669024996, normalized depth 0.8330031669024996, value_metric 16.72686207128899
# Processing depth map: stingray_frame_000002_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8763454801874347, normalized depth 0.8763454801874347, value_metric 17.57637141167372
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9611481706084496, normalized depth 0.9611481706084496, value_metric 19.238504143925613
# Processing depth map: stingray_frame_000003_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8668634275055733, normalized depth 0.8668634275055733, value_metric 17.390523179109238
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9678593086719223, normalized depth 0.9678593086719223, value_metric 19.370042449969677
# Processing depth map: stingray_frame_000004_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8814487511942134, normalized depth 0.8814487511942134, value_metric 17.676395523406583
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9494912741728992, normalized depth 0.9494912741728992, value_metric 19.010028973788824
# Processing depth map: stingray_frame_000005_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.872080433101315, normalized depth 0.872080433101315, value_metric 17.492776488785776
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9476180850347011, normalized depth 0.9476180850347011, value_metric 18.973314466680144
# Processing depth map: stingray_frame_000006_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8542900686956918, normalized depth 0.8542900686956918, value_metric 17.14408534643556
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9291018125463244, normalized depth 0.9291018125463244, value_metric 18.610395525907958
# Processing depth map: stingray_frame_000007_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8346583412947546, normalized depth 0.8346583412947546, value_metric 16.75930348937719
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8834849403678998, normalized depth 0.8834849403678998, value_metric 17.716304831210838
# Processing depth map: stingray_frame_000008_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8274282334743643, normalized depth 0.8274282334743643, value_metric 16.617593376097542
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8800215618893606, normalized depth 0.8800215618893606, value_metric 17.648422613031467
# Processing depth map: stingray_frame_000009_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8644772758291253, normalized depth 0.8644772758291253, value_metric 17.343754606250855
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9511623205983423, normalized depth 0.9511623205983423, value_metric 19.04278148372751
# Processing depth map: stingray_frame_000010_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8395637141167374, normalized depth 0.8395637141167374, value_metric 16.85544879668805
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8995485479415135, normalized depth 0.8995485479415135, value_metric 18.031151539653663
# Processing depth map: stingray_frame_000011_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.785562531277012, normalized depth 0.785562531277012, value_metric 15.797025613029437
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8415066370190686, normalized depth 0.8415066370190686, value_metric 16.893530085573744
# Processing depth map: stingray_frame_000012_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8468404531186026, normalized depth 0.8468404531186026, value_metric 16.99807288112461
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9374435684926891, normalized depth 0.9374435684926891, value_metric 18.773893942456706
# Processing depth map: stingray_frame_000013_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.850105773167736, normalized depth 0.850105773167736, value_metric 17.062073154087624
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9481032275453136, normalized depth 0.9481032275453136, value_metric 18.982823259888146
# Processing depth map: stingray_frame_000014_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8877257631590922, normalized depth 0.8877257631590922, value_metric 17.79942495791821
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9622397412573276, normalized depth 0.9622397412573276, value_metric 19.259898928643622
# Processing depth map: stingray_frame_000015_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8698239388562852, normalized depth 0.8698239388562852, value_metric 17.44854920158319
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9441277541944613, normalized depth 0.9441277541944613, value_metric 18.90490398221144
# Processing depth map: stingray_frame_000016_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8700013648150677, normalized depth 0.8700013648150677, value_metric 17.452026750375328
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.946674752375177, normalized depth 0.946674752375177, value_metric 18.954825146553468
# Processing depth map: stingray_frame_000017_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8591886174423367, normalized depth 0.8591886174423367, value_metric 17.240096901869798
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9416077083754464, normalized depth 0.9416077083754464, value_metric 18.85551108415875
# Processing depth map: stingray_frame_000018_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8415893271461717, normalized depth 0.8415893271461717, value_metric 16.895150812064966
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8875951755272559, normalized depth 0.8875951755272559, value_metric 17.796865440334216
# Processing depth map: stingray_frame_000019_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8451412583594924, normalized depth 0.8451412583594924, value_metric 16.96476866384605
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9433730880668418, normalized depth 0.9433730880668418, value_metric 18.8901125261101
# Processing depth map: stingray_frame_000020_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8713491196942815, normalized depth 0.8713491196942815, value_metric 17.478442746007918
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9633043595445051, normalized depth 0.9633043595445051, value_metric 19.2807654470723
# Processing depth map: stingray_frame_000021_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8374311905736774, normalized depth 0.8374311905736774, value_metric 16.813651335244078
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.914870965568358, normalized depth 0.914870965568358, value_metric 18.33147092513982
# Processing depth map: stingray_frame_000022_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.7822096355943771, normalized depth 0.7822096355943771, value_metric 15.731308857649791
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.7733710666397143, normalized depth 0.7733710666397143, value_metric 15.558072906138403
# Processing depth map: stingray_frame_000023_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8668270324371049, normalized depth 0.8668270324371049, value_metric 17.389809835767256
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9293443838016306, normalized depth 0.9293443838016306, value_metric 18.61514992251196
# Processing depth map: stingray_frame_000024_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8378099267549247, normalized depth 0.8378099267549247, value_metric 16.821074564396525
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9112863014621658, normalized depth 0.9112863014621658, value_metric 18.26121150865845
# Processing depth map: stingray_frame_000025_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.852389563714117, normalized depth 0.852389563714117, value_metric 17.106835448796694
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9351795701098309, normalized depth 0.9351795701098309, value_metric 18.729519574152686
# Processing depth map: stingray_frame_000026_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8545345980619627, normalized depth 0.8545345980619627, value_metric 17.14887812201447
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9450845630348359, normalized depth 0.9450845630348359, value_metric 18.923657435482784
# Processing depth map: stingray_frame_000027_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8635730858468679, normalized depth 0.8635730858468679, value_metric 17.32603248259861
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9564854120342294, normalized depth 0.9564854120342294, value_metric 19.147114075870896
# Processing depth map: stingray_frame_000028_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.821465128975024, normalized depth 0.821465128975024, value_metric 16.50071652791047
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9055993531433195, normalized depth 0.9055993531433195, value_metric 18.149747321609063
# Processing depth map: stingray_frame_000029_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8628417724398345, normalized depth 0.8628417724398345, value_metric 17.311698739820756
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9593154100128023, normalized depth 0.9593154100128023, value_metric 19.202582036250924
# Processing depth map: stingray_frame_000030_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.860738819889905, normalized depth 0.860738819889905, value_metric 17.27048086984214
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9184286773128495, normalized depth 0.9184286773128495, value_metric 18.40120207533185
# Processing depth map: stingray_frame_000031_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8085960602338383, normalized depth 0.8085960602338383, value_metric 16.24848278058323
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8404824472744423, normalized depth 0.8404824472744423, value_metric 16.87345596657907
# Processing depth map: stingray_frame_000032_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.837108184341022, normalized depth 0.837108184341022, value_metric 16.80732041308403
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9121218246748873, normalized depth 0.9121218246748873, value_metric 18.277587763627793
# Processing depth map: stingray_frame_000033_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8180781129157, normalized depth 0.8180781129157, value_metric 16.43433101314772
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8508186779866586, normalized depth 0.8508186779866586, value_metric 17.076046088538508
# Processing depth map: stingray_frame_000034_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8443735498839908, normalized depth 0.8443735498839908, value_metric 16.94972157772622
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9233205309615256, normalized depth 0.9233205309615256, value_metric 18.4970824068459
# Processing depth map: stingray_frame_000035_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8259530958555117, normalized depth 0.8259530958555117, value_metric 16.58868067876803
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9346000943332661, normalized depth 0.9346000943332661, value_metric 18.718161848932017
# Processing depth map: stingray_frame_000036_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.841022928893135, normalized depth 0.841022928893135, value_metric 16.884049406305447
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9592210767468499, normalized depth 0.9592210767468499, value_metric 19.200733104238257
# Processing depth map: stingray_frame_000037_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8487932760111006, normalized depth 0.8487932760111006, value_metric 17.03634820981757
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9446668014284751, normalized depth 0.9446668014284751, value_metric 18.915469307998112
# Processing depth map: stingray_frame_000038_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.84465447431873, normalized depth 0.84465447431873, value_metric 16.955227696647107
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9014756418031131, normalized depth 0.9014756418031131, value_metric 18.068922579341017
# Processing depth map: stingray_frame_000039_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8046676675310497, normalized depth 0.8046676675310497, value_metric 16.171486283608573
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8071558520315343, normalized depth 0.8071558520315343, value_metric 16.22025469981807
# Processing depth map: stingray_frame_000040_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8400277512397072, normalized depth 0.8400277512397072, value_metric 16.86454392429826
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9005457853244393, normalized depth 0.9005457853244393, value_metric 18.05069739235901
# Processing depth map: stingray_frame_000041_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.876023611300669, normalized depth 0.876023611300669, value_metric 17.57006278149311
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9578330301192642, normalized depth 0.9578330301192642, value_metric 19.17352739033758
# Processing depth map: stingray_frame_000042_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8329352622719622, normalized depth 0.8329352622719622, value_metric 16.72553114053046
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8777036587831012, normalized depth 0.8777036587831012, value_metric 17.602991712148782
# Processing depth map: stingray_frame_000043_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8714856012010376, normalized depth 0.8714856012010376, value_metric 17.481117783540338
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9552321272151472, normalized depth 0.9552321272151472, value_metric 19.122549693416886
# Processing depth map: stingray_frame_000044_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8372890223374734, normalized depth 0.8372890223374734, value_metric 16.810864837814478
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9508523684387844, normalized depth 0.9508523684387844, value_metric 19.036706421400176
# Processing depth map: stingray_frame_000045_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.855195396023839, normalized depth 0.855195396023839, value_metric 17.161829762067242
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9549491274172899, normalized depth 0.9549491274172899, value_metric 19.11700289737888
# Processing depth map: stingray_frame_000046_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.816823620399436, normalized depth 0.816823620399436, value_metric 16.409742959828947
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9082406845899874, normalized depth 0.9082406845899874, value_metric 18.201517417963753
# Processing depth map: stingray_frame_000047_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8384388790318913, normalized depth 0.8384388790318913, value_metric 16.83340202902507
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9179839633447883, normalized depth 0.9179839633447883, value_metric 18.39248568155785
# Processing depth map: stingray_frame_000048_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8113871070469952, normalized depth 0.8113871070469952, value_metric 16.303187298121106
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8795094670170476, normalized depth 0.8795094670170476, value_metric 17.638385553534132
# Processing depth map: stingray_frame_000049_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8416643919748876, normalized depth 0.8416643919748876, value_metric 16.896622082707797
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9478876086517081, normalized depth 0.9478876086517081, value_metric 18.97859712957348
# Processing depth map: stingray_frame_000050_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8678768026932352, normalized depth 0.8678768026932352, value_metric 17.41038533278741
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.948116703726164, normalized depth 0.948116703726164, value_metric 18.983087393032815
# Processing depth map: stingray_frame_000051_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8237637050179702, normalized depth 0.8237637050179702, value_metric 16.545768618352216
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8708442827302745, normalized depth 0.8708442827302745, value_metric 17.46854794151338
# Processing depth map: stingray_frame_000052_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8521473090396252, normalized depth 0.8521473090396252, value_metric 17.102087257176652
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9498955595984097, normalized depth 0.9498955595984097, value_metric 19.017952968128828
# Processing depth map: stingray_frame_000053_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.863461625949684, normalized depth 0.863461625949684, value_metric 17.323847868613807
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9611212182467489, normalized depth 0.9611212182467489, value_metric 19.237975877636277
# Processing depth map: stingray_frame_000054_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8364269141531324, normalized depth 0.8364269141531324, value_metric 16.793967517401395
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9524695101408259, normalized depth 0.9524695101408259, value_metric 19.06840239876019
# Processing depth map: stingray_frame_000055_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8411378008279881, normalized depth 0.8411378008279881, value_metric 16.886300896228565
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9442625160029646, normalized depth 0.9442625160029646, value_metric 18.907545313658108
# Processing depth map: stingray_frame_000056_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8522735544333744, normalized depth 0.8522735544333744, value_metric 17.10456166689414
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9460278956943601, normalized depth 0.9460278956943601, value_metric 18.942146755609457
# Processing depth map: stingray_frame_000057_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.823761430326191, normalized depth 0.823761430326191, value_metric 16.54572403439334
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8875816993464055, normalized depth 0.8875816993464055, value_metric 17.796601307189547
# Processing depth map: stingray_frame_000058_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8418873117692554, normalized depth 0.8418873117692554, value_metric 16.900991310677405
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9339801900141499, normalized depth 0.9339801900141499, value_metric 18.70601172427734
# Processing depth map: stingray_frame_000059_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8399663345616671, normalized depth 0.8399663345616671, value_metric 16.863340157408675
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9570244592682434, normalized depth 0.9570244592682434, value_metric 19.15767940165757
# Processing depth map: stingray_frame_000060_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8333890632819254, normalized depth 0.8333890632819254, value_metric 16.73442564032574
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.9245199110572063, normalized depth 0.9245199110572063, value_metric 18.520590256721245
# Processing depth map: stingray_frame_000061_pred04.png
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.7931383922478507, normalized depth 0.7931383922478507, value_metric 15.945512488057874
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8118051344249039, normalized depth 0.8118051344249039, value_metric 16.311380634728117
#
# Processing depth maps 61 to 121 using annotations from stingray_frame_000002.png
# Processing depth map: stingray_frame_000062_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8314495530012772, normalized depth 0.8314495530012772, value_metric 16.696411238825032
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9100269491682931, normalized depth 0.9100269491682931, value_metric 18.236528203698544
# Processing depth map: stingray_frame_000063_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.7977556156562243, normalized depth 0.7977556156562243, value_metric 16.036010066861998
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8959390391227583, normalized depth 0.8959390391227583, value_metric 17.960405166806062
# Processing depth map: stingray_frame_000064_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8276106227931788, normalized depth 0.8276106227931788, value_metric 16.621168206746304
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9494842486757736, normalized depth 0.9494842486757736, value_metric 19.009891274045163
# Processing depth map: stingray_frame_000065_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8152561790999926, normalized depth 0.8152561790999926, value_metric 16.379021110359854
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9535545023696683, normalized depth 0.9535545023696683, value_metric 19.0896682464455
# Processing depth map: stingray_frame_000066_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8507399894823832, normalized depth 0.8507399894823832, value_metric 17.07450379385471
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9276461295418642, normalized depth 0.9276461295418642, value_metric 18.58186413902054
# Processing depth map: stingray_frame_000067_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8744684847118926, normalized depth 0.8744684847118926, value_metric 17.539582300353096
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9558405352662392, normalized depth 0.9558405352662392, value_metric 19.13447449121829
# Processing depth map: stingray_frame_000068_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.838349861017204, normalized depth 0.838349861017204, value_metric 16.831657275937197
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9463804479137626, normalized depth 0.9463804479137626, value_metric 18.949056779109746
# Processing depth map: stingray_frame_000069_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.833592517466757, normalized depth 0.833592517466757, value_metric 16.738413342348437
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9568069881981228, normalized depth 0.9568069881981228, value_metric 19.153416968683207
# Processing depth map: stingray_frame_000070_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8528003155285104, normalized depth 0.8528003155285104, value_metric 17.114886184358806
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9574574853638137, normalized depth 0.9574574853638137, value_metric 19.16616671313075
# Processing depth map: stingray_frame_000071_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8507381113364887, normalized depth 0.8507381113364887, value_metric 17.07446698219518
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9564910324319302, normalized depth 0.9564910324319302, value_metric 19.14722423566583
# Processing depth map: stingray_frame_000072_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.843711967545639, normalized depth 0.843711967545639, value_metric 16.936754563894524
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.950394944707741, normalized depth 0.950394944707741, value_metric 19.027740916271725
# Processing depth map: stingray_frame_000073_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8480974382090002, normalized depth 0.8480974382090002, value_metric 17.022709788896403
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9488895084099992, normalized depth 0.9488895084099992, value_metric 18.998234364835984
# Processing depth map: stingray_frame_000074_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8511851100593495, normalized depth 0.8511851100593495, value_metric 17.08322815716325
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9565653749651519, normalized depth 0.9565653749651519, value_metric 19.148681349316977
# Processing depth map: stingray_frame_000075_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8078976034858388, normalized depth 0.8078976034858388, value_metric 16.234793028322443
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8220425611002697, normalized depth 0.8220425611002697, value_metric 16.51203419756529
# Processing depth map: stingray_frame_000076_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8567106152805952, normalized depth 0.8567106152805952, value_metric 17.191528059499667
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9580522256295882, normalized depth 0.9580522256295882, value_metric 19.17782362233993
# Processing depth map: stingray_frame_000077_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8468991811283904, normalized depth 0.8468991811283904, value_metric 16.999223950116452
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9474770002787846, normalized depth 0.9474770002787846, value_metric 18.970549205464177
# Processing depth map: stingray_frame_000078_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8078675531515289, normalized depth 0.8078675531515289, value_metric 16.234204041769967
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8775578477836634, normalized depth 0.8775578477836634, value_metric 17.600133816559804
# Processing depth map: stingray_frame_000079_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8417849898580123, normalized depth 0.8417849898580123, value_metric 16.89898580121704
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9454511662484899, normalized depth 0.9454511662484899, value_metric 18.930842858470402
# Processing depth map: stingray_frame_000080_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8487435203966646, normalized depth 0.8487435203966646, value_metric 17.035372999774626
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9569928445311775, normalized depth 0.9569928445311775, value_metric 19.15705975281108
# Processing depth map: stingray_frame_000081_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8599353917812338, normalized depth 0.8599353917812338, value_metric 17.25473367891218
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9500418176749373, normalized depth 0.9500418176749373, value_metric 19.02081962642877
# Processing depth map: stingray_frame_000082_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.7028641724889189, normalized depth 0.7028641724889189, value_metric 14.176137780782812
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.6896756806988199, normalized depth 0.6896756806988199, value_metric 13.917643341696872
# Processing depth map: stingray_frame_000083_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.826791751183232, normalized depth 0.826791751183232, value_metric 16.60511832319135
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8838955487408237, normalized depth 0.8838955487408237, value_metric 17.724352755320144
# Processing depth map: stingray_frame_000084_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8367496807151981, normalized depth 0.8367496807151981, value_metric 16.80029374201788
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9403772883561008, normalized depth 0.9403772883561008, value_metric 18.831394851779574
# Processing depth map: stingray_frame_000085_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.7869450078882129, normalized depth 0.7869450078882129, value_metric 15.824122154608974
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8729671963572161, normalized depth 0.8729671963572161, value_metric 17.510157048601435
# Processing depth map: stingray_frame_000086_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.7779768612425815, normalized depth 0.7779768612425815, value_metric 15.648346480354599
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8428584704023789, normalized depth 0.8428584704023789, value_metric 16.920026019886627
# Processing depth map: stingray_frame_000087_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8314495530012771, normalized depth 0.8314495530012771, value_metric 16.696411238825032
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8942477464919618, normalized depth 0.8942477464919618, value_metric 17.92725583124245
# Processing depth map: stingray_frame_000088_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8504939523702203, normalized depth 0.8504939523702203, value_metric 17.069681466456316
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9209553015519006, normalized depth 0.9209553015519006, value_metric 18.450723910417253
# Processing depth map: stingray_frame_000089_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8437006986702729, normalized depth 0.8437006986702729, value_metric 16.93653369393735
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9297834773719915, normalized depth 0.9297834773719915, value_metric 18.623756156491034
# Processing depth map: stingray_frame_000090_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8669427541131397, normalized depth 0.8669427541131397, value_metric 17.39207798061754
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9610630982250722, normalized depth 0.9610630982250722, value_metric 19.236836725211415
# Processing depth map: stingray_frame_000091_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8642983246938624, normalized depth 0.8642983246938624, value_metric 17.340247163999702
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.966583031316792, normalized depth 0.966583031316792, value_metric 19.345027413809124
# Processing depth map: stingray_frame_000092_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.869979716024341, normalized depth 0.869979716024341, value_metric 17.451602434077085
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9611374407582939, normalized depth 0.9611374407582939, value_metric 19.23829383886256
# Processing depth map: stingray_frame_000093_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.868927954323492, normalized depth 0.868927954323492, value_metric 17.430987904740444
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9472353870458137, normalized depth 0.9472353870458137, value_metric 18.965813586097948
# Processing depth map: stingray_frame_000094_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8613552700773798, normalized depth 0.8613552700773798, value_metric 17.282563293516642
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9568627450980391, normalized depth 0.9568627450980391, value_metric 19.154509803921567
# Processing depth map: stingray_frame_000095_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8459732552024641, normalized depth 0.8459732552024641, value_metric 16.9810758019683
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9541492426354428, normalized depth 0.9541492426354428, value_metric 19.101325155654678
# Processing depth map: stingray_frame_000096_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.856282398016678, normalized depth 0.856282398016678, value_metric 17.18313500112689
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9676795836818138, normalized depth 0.9676795836818138, value_metric 19.36651984016355
# Processing depth map: stingray_frame_000097_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8837859664938774, normalized depth 0.8837859664938774, value_metric 17.722204943279998
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.94299786265217, normalized depth 0.94299786265217, value_metric 18.882758107982532
# Processing depth map: stingray_frame_000098_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8521072796934868, normalized depth 0.8521072796934868, value_metric 17.10130268199234
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9580336399962828, normalized depth 0.9580336399962828, value_metric 19.177459343927143
# Processing depth map: stingray_frame_000099_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8121985575839532, normalized depth 0.8121985575839532, value_metric 16.319091728645482
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.929597621038937, normalized depth 0.929597621038937, value_metric 18.620113372363164
# Processing depth map: stingray_frame_000100_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8009334385095035, normalized depth 0.8009334385095035, value_metric 16.09829539478627
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.902704209645944, normalized depth 0.902704209645944, value_metric 18.0930025090605
# Processing depth map: stingray_frame_000101_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8136729021110362, normalized depth 0.8136729021110362, value_metric 16.34798888137631
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9212340860514822, normalized depth 0.9212340860514822, value_metric 18.45618808660905
# Processing depth map: stingray_frame_000102_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.7995530012771392, normalized depth 0.7995530012771392, value_metric 16.07123882503193
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8795650961806526, normalized depth 0.8795650961806526, value_metric 17.63947588514079
# Processing depth map: stingray_frame_000103_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8377657576440539, normalized depth 0.8377657576440539, value_metric 16.820208849823455
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9272186599758387, normalized depth 0.9272186599758387, value_metric 18.57348573552644
# Processing depth map: stingray_frame_000104_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8461347757493803, normalized depth 0.8461347757493803, value_metric 16.984241604687856
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9552272093671592, normalized depth 0.9552272093671592, value_metric 19.12245330359632
# Processing depth map: stingray_frame_000105_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8237491548343475, normalized depth 0.8237491548343475, value_metric 16.545483434753212
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9188179537217731, normalized depth 0.9188179537217731, value_metric 18.408831892946754
# Processing depth map: stingray_frame_000106_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.7993032078731876, normalized depth 0.7993032078731876, value_metric 16.06634287431448
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8702536938946197, normalized depth 0.8702536938946197, value_metric 17.456972400334546
# Processing depth map: stingray_frame_000107_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.7507324768988056, normalized depth 0.7507324768988056, value_metric 15.114356547216591
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8225072019329059, normalized depth 0.8225072019329059, value_metric 16.521141157884955
# Processing depth map: stingray_frame_000108_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8319322364961311, normalized depth 0.8319322364961311, value_metric 16.70587183532417
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9107517888672059, normalized depth 0.9107517888672059, value_metric 18.250735061797236
# Processing depth map: stingray_frame_000109_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8514668319435055, normalized depth 0.8514668319435055, value_metric 17.08874990609271
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9455069231484062, normalized depth 0.9455069231484062, value_metric 18.931935693708763
# Processing depth map: stingray_frame_000110_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8400927804071822, normalized depth 0.8400927804071822, value_metric 16.86581849598077
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9440386581172753, normalized depth 0.9440386581172753, value_metric 18.903157699098596
# Processing depth map: stingray_frame_000111_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8418150401923222, normalized depth 0.8418150401923222, value_metric 16.899574787769517
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9426075643527553, normalized depth 0.9426075643527553, value_metric 18.875108261314004
# Processing depth map: stingray_frame_000112_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.834317481781985, normalized depth 0.834317481781985, value_metric 16.752622642926905
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9312889136697333, normalized depth 0.9312889136697333, value_metric 18.65326270792677
# Processing depth map: stingray_frame_000113_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.81836451055518, normalized depth 0.81836451055518, value_metric 16.439944406881526
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.8147755784778368, normalized depth 0.8147755784778368, value_metric 16.3696013381656
# Processing depth map: stingray_frame_000114_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.7929118773946362, normalized depth 0.7929118773946362, value_metric 15.94107279693487
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.7692593625127776, normalized depth 0.7692593625127776, value_metric 15.477483505250442
# Processing depth map: stingray_frame_000115_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.7845879347907747, normalized depth 0.7845879347907747, value_metric 15.777923521899186
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.7963014589722147, normalized depth 0.7963014589722147, value_metric 16.00750859585541
# Processing depth map: stingray_frame_000116_pred04.png
# Processing annotation ID 50, category ID 5, category name 90
# ...
# Annotation ID 53: mean depth 0.863101998752475, normalized depth 0.863101998752475, value_metric 17.31679917554851
# Processing depth map: stingray_frame_000150_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9580392156862745, normalized depth 0.9580392156862745, value_metric 19.17756862745098
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8696835082580752, normalized depth 0.8696835082580752, value_metric 17.445796761858272
# Processing depth map: stingray_frame_000151_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9611010558069382, normalized depth 0.9611010558069382, value_metric 19.23758069381599
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8802722859544927, normalized depth 0.8802722859544927, value_metric 17.653336804708058
# Processing depth map: stingray_frame_000152_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9539517345399698, normalized depth 0.9539517345399698, value_metric 19.097453996983408
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8600905811840645, normalized depth 0.8600905811840645, value_metric 17.257775391207662
# Processing depth map: stingray_frame_000153_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9631221719457014, normalized depth 0.9631221719457014, value_metric 19.277194570135748
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8566680226724163, normalized depth 0.8566680226724163, value_metric 17.190693244379357
# Processing depth map: stingray_frame_000154_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.958763197586727, normalized depth 0.958763197586727, value_metric 19.191758672699848
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8654994169175277, normalized depth 0.8654994169175277, value_metric 17.363788571583544
# Processing depth map: stingray_frame_000155_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9460180995475115, normalized depth 0.9460180995475115, value_metric 18.941954751131224
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8454695847910396, normalized depth 0.8454695847910396, value_metric 16.971203861904375
# Processing depth map: stingray_frame_000156_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9164555052790349, normalized depth 0.9164555052790349, value_metric 18.362527903469083
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8430927779133786, normalized depth 0.8430927779133786, value_metric 16.92461844710222
# Processing depth map: stingray_frame_000157_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9532730015082957, normalized depth 0.9532730015082957, value_metric 19.084150829562596
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8543118270821471, normalized depth 0.8543118270821471, value_metric 17.144511810810084
# Processing depth map: stingray_frame_000158_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9129411764705884, normalized depth 0.9129411764705884, value_metric 18.29364705882353
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8322544951590596, normalized depth 0.8322544951590596, value_metric 16.71218810511757
# Processing depth map: stingray_frame_000159_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9609351432880844, normalized depth 0.9609351432880844, value_metric 19.234328808446453
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8664247552409624, normalized depth 0.8664247552409624, value_metric 17.38192520272286
# Processing depth map: stingray_frame_000160_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9703016591251884, normalized depth 0.9703016591251884, value_metric 19.417912518853694
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8727545900794622, normalized depth 0.8727545900794622, value_metric 17.505989965557458
# Processing depth map: stingray_frame_000161_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9720211161387633, normalized depth 0.9720211161387633, value_metric 19.45161387631976
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8723922653432051, normalized depth 0.8723922653432051, value_metric 17.49888840072682
# Processing depth map: stingray_frame_000162_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9714781297134237, normalized depth 0.9714781297134237, value_metric 19.440971342383104
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8824484039812331, normalized depth 0.8824484039812331, value_metric 17.69598871803217
# Processing depth map: stingray_frame_000163_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9696832579185519, normalized depth 0.9696832579185519, value_metric 19.405791855203617
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.880246250644103, normalized depth 0.880246250644103, value_metric 17.65282651262442
# Processing depth map: stingray_frame_000164_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9669079939668174, normalized depth 0.9669079939668174, value_metric 19.35139668174962
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8641011037886802, normalized depth 0.8641011037886802, value_metric 17.33638163425813
# Processing depth map: stingray_frame_000165_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.962760180995475, normalized depth 0.962760180995475, value_metric 19.27009954751131
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8819146801182439, normalized depth 0.8819146801182439, value_metric 17.68552773031758
# Processing depth map: stingray_frame_000166_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.8520060331825037, normalized depth 0.8520060331825037, value_metric 17.09931825037707
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.792739402815068, normalized depth 0.792739402815068, value_metric 15.937692295175335
# Processing depth map: stingray_frame_000167_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9291251885369535, normalized depth 0.9291251885369535, value_metric 18.610853695324288
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8411216879559571, normalized depth 0.8411216879559571, value_metric 16.88598508393676
# Processing depth map: stingray_frame_000168_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9213122171945702, normalized depth 0.9213122171945702, value_metric 18.457719457013578
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8437078621213355, normalized depth 0.8437078621213355, value_metric 16.936674097578177
# Processing depth map: stingray_frame_000169_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.8660633484162898, normalized depth 0.8660633484162898, value_metric 17.37484162895928
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8108285195129228, normalized depth 0.8108285195129228, value_metric 16.292238982453288
# Processing depth map: stingray_frame_000170_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.8741779788838614, normalized depth 0.8741779788838614, value_metric 17.53388838612368
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8223252786591816, normalized depth 0.8223252786591816, value_metric 16.517575461719957
# Processing depth map: stingray_frame_000171_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9505429864253394, normalized depth 0.9505429864253394, value_metric 19.030642533936653
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8405803704607708, normalized depth 0.8405803704607708, value_metric 16.87537526103111
# Processing depth map: stingray_frame_000172_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9525942684766214, normalized depth 0.9525942684766214, value_metric 19.07084766214178
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8432066823963336, normalized depth 0.8432066823963336, value_metric 16.926850974968136
# Processing depth map: stingray_frame_000173_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9552187028657617, normalized depth 0.9552187028657617, value_metric 19.12228657616893
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8510010034442548, normalized depth 0.8510010034442548, value_metric 17.079619667507394
# Processing depth map: stingray_frame_000174_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9594117647058823, normalized depth 0.9594117647058823, value_metric 19.204470588235292
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8602109944946167, normalized depth 0.8602109944946167, value_metric 17.260135492094488
# Processing depth map: stingray_frame_000175_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.8911010558069384, normalized depth 0.8911010558069384, value_metric 17.865580693815993
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8100225096954413, normalized depth 0.8100225096954413, value_metric 16.27644119003065
# Processing depth map: stingray_frame_000176_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9667571644042233, normalized depth 0.9667571644042233, value_metric 19.348440422322778
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8572614107883819, normalized depth 0.8572614107883819, value_metric 17.202323651452286
# Processing depth map: stingray_frame_000177_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9585671191553544, normalized depth 0.9585671191553544, value_metric 19.187915535444947
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8693656605104007, normalized depth 0.8693656605104007, value_metric 17.439566946003854
# Processing depth map: stingray_frame_000178_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9461085972850679, normalized depth 0.9461085972850679, value_metric 18.94372850678733
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8570194993626774, normalized depth 0.8570194993626774, value_metric 17.197582187508477
# Processing depth map: stingray_frame_000179_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.954027149321267, normalized depth 0.954027149321267, value_metric 19.098932126696834
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8700328153391372, normalized depth 0.8700328153391372, value_metric 17.45264318064709
# Processing depth map: stingray_frame_000180_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9630618401206635, normalized depth 0.9630618401206635, value_metric 19.276012066365006
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8829409052694387, normalized depth 0.8829409052694387, value_metric 17.705641743281
# Processing depth map: stingray_frame_000181_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9632880844645549, normalized depth 0.9632880844645549, value_metric 19.280446455505277
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8776926206167116, normalized depth 0.8776926206167116, value_metric 17.60277536408755
# Processing depth map: stingray_frame_000182_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9418250377073908, normalized depth 0.9418250377073908, value_metric 18.85977073906486
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8690326254983323, normalized depth 0.8690326254983323, value_metric 17.43303945976731
# Processing depth map: stingray_frame_000183_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9610105580693816, normalized depth 0.9610105580693816, value_metric 19.23580693815988
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8683535378190006, normalized depth 0.8683535378190006, value_metric 17.419729341252413
# Processing depth map: stingray_frame_000184_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9059276018099549, normalized depth 0.9059276018099549, value_metric 18.156180995475115
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8454164293656607, normalized depth 0.8454164293656607, value_metric 16.97016201556695
# Processing depth map: stingray_frame_000185_pred04.png
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9433031674208145, normalized depth 0.9433031674208145, value_metric 18.888742081447965
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8735106988853635, normalized depth 0.8735106988853635, value_metric 17.520809698153123
#
# Results DataFrame:
#                      depth_map_file           annotation_image  annotation_id  \
# 0  stingray_frame_000001_pred04.png  stingray_frame_000001.png             48
# 1  stingray_frame_000001_pred04.png  stingray_frame_000001.png             49
# 2  stingray_frame_000002_pred04.png  stingray_frame_000001.png             48
# 3  stingray_frame_000002_pred04.png  stingray_frame_000001.png             49
# 4  stingray_frame_000003_pred04.png  stingray_frame_000001.png             48
#
#    category_id category_name  normalized_depth  z-min  z-max  value_metric
# 0            5            90          0.806614    0.4   20.0     16.209628
# 1            4            80          0.833003    0.4   20.0     16.726862
# 2            5            90          0.876345    0.4   20.0     17.576371
# 3            4            80          0.961148    0.4   20.0     19.238504
# 4            5            90          0.866863    0.4   20.0     17.390523
#
# Results saved to ../data/deigo/results_stingray_vid.csv
