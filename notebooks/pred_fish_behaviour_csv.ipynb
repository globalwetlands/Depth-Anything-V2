# %%
import os
import numpy as np
import pandas as pd
import cv2
from pycocotools.coco import COCO
from pycocotools import mask as maskUtils

# Define directories
image_directory = '../data/fish-behaviour/annotations/images/'  # Original Images
depth_map_directory = '../data/fish-behaviour/depth-maps/'  # Depth Map Images
mask_directory = '../data/fish-behaviour/masks/'    # Directory to save masks
json_file = '../data/fish-behaviour/annotations/annotations/instances_default.json'  # JSON file

# Create mask directory if it doesn't exist
os.makedirs(mask_directory, exist_ok=True)

# Load the COCO annotations
coco = COCO(json_file)

# Create a mapping from category_id to category_name
cats = coco.loadCats(coco.getCatIds())
category_mapping = {cat['id']: cat['name'] for cat in cats}
print("Category mapping:")
print(category_mapping)

def load_depth_map(img_name):
    # Construct the depth map filename
    depth_map_filename = f"{img_name}_pred04.png"
    depth_map_path = os.path.join(depth_map_directory, depth_map_filename)
    
    # Check if the depth map exists
    if not os.path.exists(depth_map_path):
        print(f"Depth map for image {img_name} not found at {depth_map_path}.")
        return None
    
    # Load the depth map image
    depth_map = cv2.imread(depth_map_path, cv2.IMREAD_GRAYSCALE)
    if depth_map is None:
        print(f"Failed to load depth map for image {img_name}.")
        return None
    
    return depth_map

def create_mask_from_annotation(ann, img_height, img_width):
    segmentation = ann['segmentation']
    
    if isinstance(segmentation, list):  # Polygon format
        mask = np.zeros((img_height, img_width), dtype=np.uint8)
        # Convert polygons to a mask
        for poly in segmentation:
            poly = np.array(poly).reshape((-1, 2))  # Reshape to (N, 2)
            cv2.fillPoly(mask, [np.int32(poly)], 1)  # Fill the polygon with 1's

    elif isinstance(segmentation, dict) and 'counts' in segmentation:  # RLE format
        rle = segmentation
        if isinstance(rle['counts'], list):  # Uncompressed RLE
            rle = maskUtils.frPyObjects([rle], img_height, img_width)
        mask = maskUtils.decode(rle)  # Decode RLE to binary mask

    else:
        mask = None  # Segmentation format not recognized

    return mask

# List to store results
results = []

# Get all image IDs
image_ids = coco.getImgIds()
print(f"Total number of images: {len(image_ids)}")

# Process each image
for img_id in image_ids:
    # Load image information
    img_info = coco.loadImgs(img_id)[0]
    img_name_with_ext = img_info['file_name']  # e.g., 'frame_000001.png'
    img_name = os.path.splitext(img_name_with_ext)[0]  # e.g., 'frame_000001'
    img_height = img_info['height']
    img_width = img_info['width']
    
    print(f"Processing image ID {img_id}, name {img_name_with_ext}")

    # Load depth map
    depth_map = load_depth_map(img_name)
    if depth_map is None:
        print(f"Skipping image {img_name_with_ext} due to missing depth map.")
        continue  # Skip if depth map is not available

    # Extract frame number from image name (assuming format 'frame_000001.png')
    frame_number_str = img_name.split('_')[-1]
    try:
        frame = int(frame_number_str)
    except ValueError:
        frame = None  # Unable to extract frame number
        print(f"Unable to extract frame number from image name {img_name_with_ext}")

    # Get annotation IDs for the image
    ann_ids = coco.getAnnIds(imgIds=img_id)
    anns = coco.loadAnns(ann_ids)
    
    print(f"Number of annotations for image {img_name_with_ext}: {len(anns)}")
    
    # Process each annotation
    for ann in anns:
        annotation_id = ann['id']
        category_id = ann['category_id']
        category_name = category_mapping.get(category_id, "Unknown")
        print(f"Processing annotation ID {annotation_id}, category ID {category_id}, category name {category_name}")
        
        # Create mask for the annotation
        mask = create_mask_from_annotation(ann, img_height, img_width)
        if mask is None:
            print(f"Failed to create mask for annotation {annotation_id}")
            continue  # Skip if mask couldn't be created
        
        # Apply the mask to the depth map to extract depth values
        depth_values = depth_map[mask == 1]
        mean_depth = depth_values.mean() if depth_values.size > 0 else 0
        normalized_depth = mean_depth / 255  # Assuming 8-bit depth map
        
        # Convert normalized depth to metric depth
        zmin = 0.4  # Minimum depth in meters
        zmax = 20.0  # Maximum depth in meters
        value_metric = (normalized_depth * (zmax - zmin)) + zmin
        
        print(f"Annotation ID {annotation_id}: mean depth {mean_depth}, normalized depth {normalized_depth}, value_metric {value_metric}")
        
        # Append the result to the list
        results.append({
            'image_name': img_name_with_ext,
            'image_id': img_id,
            'annotation_id': annotation_id,
            'frame': frame,
            'category_id': category_id,
            'category_name': category_name,
            'normalized_depth': normalized_depth,
            'z-min': zmin,
            'z-max': zmax,
            'value_metric': value_metric
        })

# Create a DataFrame from the results
results_df = pd.DataFrame(results)

# Display the DataFrame
print("Results DataFrame:")
print(results_df.head())

# Save the results to a CSV file
results_df.to_csv('../data/fish-behaviour/fish-behaviour.csv', index=False)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Category mapping:
# {1: 'Left', 2: 'Middle', 3: 'Right'}
# Total number of images: 166
# Processing image ID 1, name frame_000001.png
# Number of annotations for image frame_000001.png: 3
# Processing annotation ID 1, category ID 2, category name Middle
# Annotation ID 1: mean depth 61.78431372549019, normalized depth 0.24229142637447135, value_metric 5.1489119569396395
# Processing annotation ID 2, category ID 1, category name Left
# Annotation ID 2: mean depth 71.03296703296704, normalized depth 0.2785606550312433, value_metric 5.859788838612369
# Processing annotation ID 3, category ID 3, category name Right
# Annotation ID 3: mean depth 71.59493670886076, normalized depth 0.2807644576818069, value_metric 5.902983370563416
# Processing image ID 2, name frame_000002.png
# Number of annotations for image frame_000002.png: 3
# Processing annotation ID 4, category ID 2, category name Middle
# Annotation ID 4: mean depth 62.93333333333333, normalized depth 0.24679738562091502, value_metric 5.237228758169935
# Processing annotation ID 5, category ID 1, category name Left
# Annotation ID 5: mean depth 72.19, normalized depth 0.28309803921568627, value_metric 5.948721568627452
# Processing annotation ID 6, category ID 3, category name Right
# Annotation ID 6: mean depth 71.3013698630137, normalized depth 0.27961321514907334, value_metric 5.880419016921838
# Processing image ID 3, name frame_000003.png
# Number of annotations for image frame_000003.png: 3
# Processing annotation ID 7, category ID 3, category name Right
# Annotation ID 7: mean depth 71.05882352941177, normalized depth 0.27866205305651676, value_metric 5.861776239907729
# Processing annotation ID 8, category ID 1, category name Left
# Annotation ID 8: mean depth 71.98076923076923, normalized depth 0.28227752639517345, value_metric 5.9326395173454
# Processing annotation ID 9, category ID 2, category name Middle
# Annotation ID 9: mean depth 63.17204301075269, normalized depth 0.24773350200295172, value_metric 5.255576639257854
# Processing image ID 4, name frame_000004.png
# Number of annotations for image frame_000004.png: 3
# Processing annotation ID 10, category ID 2, category name Middle
# Annotation ID 10: mean depth 62.490196078431374, normalized depth 0.24505959246443676, value_metric 5.203168012302961
# Processing annotation ID 11, category ID 1, category name Left
# Annotation ID 11: mean depth 70.875, normalized depth 0.27794117647058825, value_metric 5.84764705882353
# Processing annotation ID 12, category ID 3, category name Right
# Annotation ID 12: mean depth 70.46969696969697, normalized depth 0.27635175282234103, value_metric 5.816494355317885
# Processing image ID 5, name frame_000005.png
# Number of annotations for image frame_000005.png: 3
# Processing annotation ID 13, category ID 1, category name Left
# Annotation ID 13: mean depth 69.18085106382979, normalized depth 0.2712974551522737, value_metric 5.717430120984566
# Processing annotation ID 14, category ID 2, category name Middle
# Annotation ID 14: mean depth 60.27368421052632, normalized depth 0.23636738906088753, value_metric 5.032800825593396
# Processing annotation ID 15, category ID 3, category name Right
# Annotation ID 15: mean depth 68.10526315789474, normalized depth 0.2670794633642931, value_metric 5.634757481940146
# Processing image ID 6, name frame_000006.png
# Number of annotations for image frame_000006.png: 3
# Processing annotation ID 16, category ID 3, category name Right
# Annotation ID 16: mean depth 66.6590909090909, normalized depth 0.26140819964349377, value_metric 5.5236007130124785
# Processing annotation ID 17, category ID 1, category name Left
# Annotation ID 17: mean depth 67.35849056603773, normalized depth 0.2641509433962264, value_metric 5.577358490566039
# Processing annotation ID 18, category ID 2, category name Middle
# Annotation ID 18: mean depth 59.03738317757009, normalized depth 0.23151914971596116, value_metric 4.937775334432839
# Processing image ID 7, name frame_000007.png
# Number of annotations for image frame_000007.png: 3
# Processing annotation ID 19, category ID 2, category name Middle
# Annotation ID 19: mean depth 59.130434782608695, normalized depth 0.2318840579710145, value_metric 4.9449275362318845
# Processing annotation ID 20, category ID 3, category name Right
# Annotation ID 20: mean depth 65.984375, normalized depth 0.2587622549019608, value_metric 5.471740196078432
# Processing annotation ID 21, category ID 1, category name Left
# Annotation ID 21: mean depth 66.88297872340425, normalized depth 0.26228619107217355, value_metric 5.540809345014602
# Processing image ID 8, name frame_000008.png
# Number of annotations for image frame_000008.png: 3
# Processing annotation ID 22, category ID 1, category name Left
# Annotation ID 22: mean depth 66.63636363636364, normalized depth 0.261319073083779, value_metric 5.521853832442069
# Processing annotation ID 23, category ID 3, category name Right
# Annotation ID 23: mean depth 65.80246913580247, normalized depth 0.2580488985717744, value_metric 5.457758412006778
# Processing annotation ID 24, category ID 2, category name Middle
# Annotation ID 24: mean depth 58.78181818181818, normalized depth 0.23051693404634582, value_metric 4.9181319073083785
# Processing image ID 9, name frame_000009.png
# Number of annotations for image frame_000009.png: 3
# Processing annotation ID 25, category ID 3, category name Right
# Annotation ID 25: mean depth 65.69767441860465, normalized depth 0.25763793889648884, value_metric 5.449703602371182
# Processing annotation ID 26, category ID 1, category name Left
# Annotation ID 26: mean depth 66.94174757281553, normalized depth 0.2625166571482962, value_metric 5.545326480106606
# Processing annotation ID 27, category ID 2, category name Middle
# Annotation ID 27: mean depth 58.81818181818182, normalized depth 0.2306595365418895, value_metric 4.920926916221035
# Processing image ID 10, name frame_000010.png
# Number of annotations for image frame_000010.png: 3
# Processing annotation ID 28, category ID 3, category name Right
# Annotation ID 28: mean depth 67.76666666666667, normalized depth 0.2657516339869281, value_metric 5.608732026143791
# Processing annotation ID 29, category ID 2, category name Middle
# Annotation ID 29: mean depth 59.953271028037385, normalized depth 0.2351108667766172, value_metric 5.0081729888216975
# Processing annotation ID 30, category ID 1, category name Left
# Annotation ID 30: mean depth 67.85436893203884, normalized depth 0.266095564439368, value_metric 5.615473063011613
# Processing image ID 11, name frame_000011.png
# Number of annotations for image frame_000011.png: 3
# Processing annotation ID 31, category ID 2, category name Middle
# Annotation ID 31: mean depth 58.717171717171716, normalized depth 0.23026341849871262, value_metric 4.913163002574768
# Processing annotation ID 32, category ID 1, category name Left
# Annotation ID 32: mean depth 66.52747252747253, normalized depth 0.26089204912734326, value_metric 5.513484162895929
# Processing annotation ID 33, category ID 3, category name Right
# Annotation ID 33: mean depth 66.58024691358025, normalized depth 0.2610990075042363, value_metric 5.5175405470830325
# Processing image ID 12, name frame_000012.png
# Number of annotations for image frame_000012.png: 3
# Processing annotation ID 34, category ID 1, category name Left
# Annotation ID 34: mean depth 65.35955056179775, normalized depth 0.25631196298744213, value_metric 5.423714474553867
# Processing annotation ID 35, category ID 3, category name Right
# Annotation ID 35: mean depth 64.36046511627907, normalized depth 0.25239398084815323, value_metric 5.3469220246238045
# Processing annotation ID 36, category ID 2, category name Middle
# Annotation ID 36: mean depth 57.85576923076923, normalized depth 0.22688536953242835, value_metric 4.846953242835596
# Processing image ID 13, name frame_000013.png
# Number of annotations for image frame_000013.png: 3
# Processing annotation ID 37, category ID 3, category name Right
# Annotation ID 37: mean depth 62.19512195121951, normalized depth 0.24390243902439024, value_metric 5.180487804878049
# Processing annotation ID 38, category ID 2, category name Middle
# Annotation ID 38: mean depth 56.869565217391305, normalized depth 0.22301790281329922, value_metric 4.771150895140665
# Processing annotation ID 39, category ID 1, category name Left
# Annotation ID 39: mean depth 63.46666666666667, normalized depth 0.2488888888888889, value_metric 5.278222222222223
# Processing image ID 14, name frame_000014.png
# Number of annotations for image frame_000014.png: 3
# Processing annotation ID 40, category ID 2, category name Middle
# Annotation ID 40: mean depth 56.676767676767675, normalized depth 0.2222618340265399, value_metric 4.756331946920183
# Processing annotation ID 41, category ID 3, category name Right
# Annotation ID 41: mean depth 62.19512195121951, normalized depth 0.24390243902439024, value_metric 5.180487804878049
# Processing annotation ID 42, category ID 1, category name Left
# Annotation ID 42: mean depth 63.955555555555556, normalized depth 0.2508061002178649, value_metric 5.315799564270153
# Processing image ID 15, name frame_000015.png
# Number of annotations for image frame_000015.png: 3
# Processing annotation ID 43, category ID 2, category name Middle
# Annotation ID 43: mean depth 54.313131313131315, normalized depth 0.21299267181620124, value_metric 4.574656367597545
# Processing annotation ID 44, category ID 1, category name Left
# Annotation ID 44: mean depth 61.086021505376344, normalized depth 0.23955302551127977, value_metric 5.095239300021084
# Processing annotation ID 45, category ID 3, category name Right
# Annotation ID 45: mean depth 59.666666666666664, normalized depth 0.23398692810457516, value_metric 4.986143790849674
# Processing image ID 16, name frame_000016.png
# Number of annotations for image frame_000016.png: 3
# Processing annotation ID 46, category ID 2, category name Middle
# Annotation ID 46: mean depth 54.42857142857143, normalized depth 0.21344537815126052, value_metric 4.583529411764707
# Processing annotation ID 47, category ID 1, category name Left
# Annotation ID 47: mean depth 61.86666666666667, normalized depth 0.24261437908496733, value_metric 5.155241830065361
# Processing annotation ID 48, category ID 3, category name Right
# Annotation ID 48: mean depth 59.67901234567901, normalized depth 0.23403534253207456, value_metric 4.9870927136286625
# Processing image ID 17, name frame_000017.png
# Number of annotations for image frame_000017.png: 3
# Processing annotation ID 49, category ID 2, category name Middle
# Annotation ID 49: mean depth 54.59139784946237, normalized depth 0.21408391313514655, value_metric 4.596044697448873
# Processing annotation ID 50, category ID 3, category name Right
# Annotation ID 50: mean depth 56.91025641025641, normalized depth 0.22317747611865257, value_metric 4.774278531925591
# Processing annotation ID 51, category ID 1, category name Left
# Annotation ID 51: mean depth 60.395604395604394, normalized depth 0.23684550743374272, value_metric 5.042171945701358
# Processing image ID 18, name frame_000018.png
# Number of annotations for image frame_000018.png: 3
# Processing annotation ID 52, category ID 3, category name Right
# Annotation ID 52: mean depth 59.217948717948715, normalized depth 0.23222724987430868, value_metric 4.9516540975364505
# Processing annotation ID 53, category ID 1, category name Left
# Annotation ID 53: mean depth 59.976470588235294, normalized depth 0.23520184544405998, value_metric 5.0099561707035765
# Processing annotation ID 54, category ID 2, category name Middle
# Annotation ID 54: mean depth 53.15151515151515, normalized depth 0.20843731431966725, value_metric 4.485371360665479
# Processing image ID 19, name frame_000019.png
# Number of annotations for image frame_000019.png: 3
# Processing annotation ID 55, category ID 2, category name Middle
# Annotation ID 55: mean depth 52.064516129032256, normalized depth 0.20417457305502845, value_metric 4.401821631878558
# Processing annotation ID 56, category ID 1, category name Left
# Annotation ID 56: mean depth 58.741573033707866, normalized depth 0.23035910993610928, value_metric 4.915038554747743
# Processing annotation ID 57, category ID 3, category name Right
# Annotation ID 57: mean depth 57.305882352941175, normalized depth 0.2247289504036909, value_metric 4.804687427912342
# Processing image ID 20, name frame_000020.png
# Number of annotations for image frame_000020.png: 3
# Processing annotation ID 58, category ID 3, category name Right
# Annotation ID 58: mean depth 57.92857142857143, normalized depth 0.22717086834733893, value_metric 4.852549019607844
# Processing annotation ID 59, category ID 1, category name Left
# Annotation ID 59: mean depth 59.91111111111111, normalized depth 0.2349455337690632, value_metric 5.004932461873639
# Processing annotation ID 60, category ID 2, category name Middle
# Annotation ID 60: mean depth 52.68131868131868, normalized depth 0.20659340659340658, value_metric 4.44923076923077
# Processing image ID 21, name frame_000021.png
# Number of annotations for image frame_000021.png: 3
# Processing annotation ID 61, category ID 2, category name Middle
# Annotation ID 61: mean depth 54.096774193548384, normalized depth 0.21214421252371915, value_metric 4.558026565464896
# Processing annotation ID 62, category ID 1, category name Left
# Annotation ID 62: mean depth 61.08988764044944, normalized depth 0.23956818682529193, value_metric 5.095536461775723
# Processing annotation ID 63, category ID 3, category name Right
# Annotation ID 63: mean depth 59.71604938271605, normalized depth 0.23418058581457274, value_metric 4.989939481965626
# Processing image ID 22, name frame_000022.png
# Number of annotations for image frame_000022.png: 3
# Processing annotation ID 64, category ID 3, category name Right
# Annotation ID 64: mean depth 58.743589743589745, normalized depth 0.23036701860231273, value_metric 4.91519356460533
# Processing annotation ID 65, category ID 2, category name Middle
# Annotation ID 65: mean depth 52.97979797979798, normalized depth 0.2077639136462666, value_metric 4.472172707466826
# Processing annotation ID 66, category ID 1, category name Left
# Annotation ID 66: mean depth 59.92941176470588, normalized depth 0.2350173010380623, value_metric 5.006339100346022
# Processing image ID 23, name frame_000023.png
# Number of annotations for image frame_000023.png: 3
# Processing annotation ID 67, category ID 1, category name Left
# Annotation ID 67: mean depth 58.81111111111111, normalized depth 0.2306318082788671, value_metric 4.920383442265796
# Processing annotation ID 68, category ID 3, category name Right
# Annotation ID 68: mean depth 57.94047619047619, normalized depth 0.22721755368814192, value_metric 4.853464052287582
# Processing annotation ID 69, category ID 2, category name Middle
# Annotation ID 69: mean depth 51.71818181818182, normalized depth 0.20281639928698753, value_metric 4.375201426024956
# Processing image ID 24, name frame_000024.png
# Number of annotations for image frame_000024.png: 3
# Processing annotation ID 70, category ID 1, category name Left
# Annotation ID 70: mean depth 61.369565217391305, normalized depth 0.24066496163682866, value_metric 5.117033248081842
# Processing annotation ID 71, category ID 2, category name Middle
# Annotation ID 71: mean depth 53.64356435643565, normalized depth 0.21036691904484567, value_metric 4.523191613278976
# Processing annotation ID 72, category ID 3, category name Right
# Annotation ID 72: mean depth 60.662921348314605, normalized depth 0.23789380920907688, value_metric 5.062718660497907
# Processing image ID 25, name frame_000025.png
# Number of annotations for image frame_000025.png: 3
# Processing annotation ID 73, category ID 1, category name Left
# Annotation ID 73: mean depth 60.888888888888886, normalized depth 0.23877995642701524, value_metric 5.080087145969499
# Processing annotation ID 74, category ID 2, category name Middle
# Annotation ID 74: mean depth 52.95, normalized depth 0.20764705882352943, value_metric 4.469882352941178
# Processing annotation ID 75, category ID 3, category name Right
# Annotation ID 75: mean depth 59.34615384615385, normalized depth 0.23273001508295627, value_metric 4.9615082956259435
# Processing image ID 26, name frame_000026.png
# Number of annotations for image frame_000026.png: 3
# Processing annotation ID 76, category ID 3, category name Right
# Annotation ID 76: mean depth 62.93827160493827, normalized depth 0.24681675139191478, value_metric 5.237608327281531
# Processing annotation ID 77, category ID 1, category name Left
# Annotation ID 77: mean depth 63.82022471910113, normalized depth 0.25027539105529856, value_metric 5.305397664683852
# Processing annotation ID 78, category ID 2, category name Middle
# Annotation ID 78: mean depth 56.46534653465346, normalized depth 0.22143273150844495, value_metric 4.740081537565522
# Processing image ID 27, name frame_000027.png
# Number of annotations for image frame_000027.png: 3
# Processing annotation ID 79, category ID 1, category name Left
# Annotation ID 79: mean depth 64.74736842105263, normalized depth 0.2539112487100103, value_metric 5.376660474716203
# Processing annotation ID 80, category ID 3, category name Right
# Annotation ID 80: mean depth 61.382716049382715, normalized depth 0.24071653352699104, value_metric 5.118044057129025
# Processing annotation ID 81, category ID 2, category name Middle
# Annotation ID 81: mean depth 56.495049504950494, normalized depth 0.22154921374490388, value_metric 4.7423645894001165
# Processing image ID 28, name frame_000028.png
# Number of annotations for image frame_000028.png: 3
# Processing annotation ID 82, category ID 2, category name Middle
# Annotation ID 82: mean depth 56.763636363636365, normalized depth 0.222602495543672, value_metric 4.763008912655972
# Processing annotation ID 83, category ID 3, category name Right
# Annotation ID 83: mean depth 61.60493827160494, normalized depth 0.24158799322198013, value_metric 5.135124667150811
# Processing annotation ID 84, category ID 1, category name Left
# Annotation ID 84: mean depth 64.78888888888889, normalized depth 0.25407407407407406, value_metric 5.3798518518518526
# Processing image ID 29, name frame_000029.png
# Number of annotations for image frame_000029.png: 3
# Processing annotation ID 85, category ID 3, category name Right
# Annotation ID 85: mean depth 59.88636363636363, normalized depth 0.23484848484848483, value_metric 5.003030303030304
# Processing annotation ID 86, category ID 1, category name Left
# Annotation ID 86: mean depth 64.44086021505376, normalized depth 0.2527092557453089, value_metric 5.353101412608055
# Processing annotation ID 87, category ID 2, category name Middle
# Annotation ID 87: mean depth 57.03703703703704, normalized depth 0.22367465504720407, value_metric 4.784023238925201
# Processing image ID 30, name frame_000030.png
# Number of annotations for image frame_000030.png: 3
# Processing annotation ID 88, category ID 1, category name Left
# Annotation ID 88: mean depth 63.346666666666664, normalized depth 0.24841830065359477, value_metric 5.268998692810459
# Processing annotation ID 89, category ID 2, category name Middle
# Annotation ID 89: mean depth 55.568627450980394, normalized depth 0.21791618608227606, value_metric 4.671157247212611
# Processing annotation ID 90, category ID 3, category name Right
# Annotation ID 90: mean depth 57.65384615384615, normalized depth 0.22609351432880845, value_metric 4.8314328808446465
# Processing image ID 31, name frame_000031.png
# Number of annotations for image frame_000031.png: 3
# Processing annotation ID 91, category ID 3, category name Right
# Annotation ID 91: mean depth 57.92307692307692, normalized depth 0.22714932126696832, value_metric 4.85212669683258
# Processing annotation ID 92, category ID 2, category name Middle
# Annotation ID 92: mean depth 54.02970297029703, normalized depth 0.21188118811881188, value_metric 4.552871287128713
# Processing annotation ID 93, category ID 1, category name Left
# Annotation ID 93: mean depth 62.19277108433735, normalized depth 0.24389321993857785, value_metric 5.180307110796127
# Processing image ID 32, name frame_000032.png
# Number of annotations for image frame_000032.png: 3
# Processing annotation ID 94, category ID 3, category name Right
# Annotation ID 94: mean depth 56.49382716049383, normalized depth 0.2215444202372307, value_metric 4.742270636649723
# Processing annotation ID 95, category ID 2, category name Middle
# Annotation ID 95: mean depth 51.84761904761905, normalized depth 0.20332399626517275, value_metric 4.385150326797386
# Processing annotation ID 96, category ID 1, category name Left
# Annotation ID 96: mean depth 59.670103092783506, normalized depth 0.2340004042854255, value_metric 4.98640792399434
# Processing image ID 33, name frame_000033.png
# Number of annotations for image frame_000033.png: 3
# Processing annotation ID 97, category ID 2, category name Middle
# Annotation ID 97: mean depth 52.13253012048193, normalized depth 0.20444129459012522, value_metric 4.407049373966455
# Processing annotation ID 98, category ID 1, category name Left
# Annotation ID 98: mean depth 59.8421052631579, normalized depth 0.2346749226006192, value_metric 4.999628482972137
# Processing annotation ID 99, category ID 3, category name Right
# Annotation ID 99: mean depth 58.62820512820513, normalized depth 0.22991452991452993, value_metric 4.906324786324787
# Processing image ID 34, name frame_000034.png
# Number of annotations for image frame_000034.png: 3
# Processing annotation ID 100, category ID 3, category name Right
# Annotation ID 100: mean depth 58.80769230769231, normalized depth 0.2306184012066365, value_metric 4.920120663650076
# Processing annotation ID 101, category ID 2, category name Middle
# Annotation ID 101: mean depth 51.71621621621622, normalized depth 0.20280869104398516, value_metric 4.375050344462109
# Processing annotation ID 102, category ID 1, category name Left
# Annotation ID 102: mean depth 60.40229885057471, normalized depth 0.2368717601983322, value_metric 5.042686499887312
# Processing image ID 35, name frame_000035.png
# Number of annotations for image frame_000035.png: 3
# Processing annotation ID 103, category ID 3, category name Right
# Annotation ID 103: mean depth 58.26923076923077, normalized depth 0.22850678733031674, value_metric 4.878733031674209
# Processing annotation ID 104, category ID 1, category name Left
# Annotation ID 104: mean depth 60.38461538461539, normalized depth 0.23680241327300153, value_metric 5.04132730015083
# Processing annotation ID 105, category ID 2, category name Middle
# Annotation ID 105: mean depth 51.8125, normalized depth 0.20318627450980392, value_metric 4.382450980392157
# Processing image ID 36, name frame_000036.png
# Number of annotations for image frame_000036.png: 0
# Processing image ID 37, name frame_000037.png
# Number of annotations for image frame_000037.png: 0
# Processing image ID 38, name frame_000038.png
# Number of annotations for image frame_000038.png: 0
# Processing image ID 39, name frame_000039.png
# Number of annotations for image frame_000039.png: 0
# Processing image ID 40, name frame_000040.png
# Number of annotations for image frame_000040.png: 0
# Processing image ID 41, name frame_000041.png
# Number of annotations for image frame_000041.png: 0
# Processing image ID 42, name frame_000042.png
# Number of annotations for image frame_000042.png: 0
# Processing image ID 43, name frame_000043.png
# Number of annotations for image frame_000043.png: 0
# Processing image ID 44, name frame_000044.png
# Number of annotations for image frame_000044.png: 0
# Processing image ID 45, name frame_000045.png
# Number of annotations for image frame_000045.png: 3
# Processing annotation ID 106, category ID 1, category name Left
# Annotation ID 106: mean depth 56.82608695652174, normalized depth 0.22284739982949703, value_metric 4.767809036658142
# Processing annotation ID 107, category ID 3, category name Right
# Annotation ID 107: mean depth 56.25333333333333, normalized depth 0.22060130718954246, value_metric 4.723785620915033
# Processing annotation ID 108, category ID 2, category name Middle
# Annotation ID 108: mean depth 48.96261682242991, normalized depth 0.19201026204874475, value_metric 4.1634011361553975
# Processing image ID 46, name frame_000046.png
# Number of annotations for image frame_000046.png: 3
# Processing annotation ID 109, category ID 2, category name Middle
# Annotation ID 109: mean depth 47.71296296296296, normalized depth 0.18710965867828613, value_metric 4.067349310094409
# Processing annotation ID 110, category ID 1, category name Left
# Annotation ID 110: mean depth 55.59375, normalized depth 0.21801470588235294, value_metric 4.673088235294118
# Processing annotation ID 111, category ID 3, category name Right
# Annotation ID 111: mean depth 55.705128205128204, normalized depth 0.2184514831573655, value_metric 4.681649069884364
# Processing image ID 47, name frame_000047.png
# Number of annotations for image frame_000047.png: 3
# Processing annotation ID 112, category ID 3, category name Right
# Annotation ID 112: mean depth 52.404761904761905, normalized depth 0.20550887021475256, value_metric 4.42797385620915
# Processing annotation ID 113, category ID 2, category name Middle
# Annotation ID 113: mean depth 47.4375, normalized depth 0.1860294117647059, value_metric 4.046176470588236
# Processing annotation ID 114, category ID 1, category name Left
# Annotation ID 114: mean depth 55.477777777777774, normalized depth 0.21755991285403048, value_metric 4.664174291938998
# Processing image ID 48, name frame_000048.png
# Number of annotations for image frame_000048.png: 0
# Processing image ID 49, name frame_000049.png
# Number of annotations for image frame_000049.png: 3
# Processing annotation ID 115, category ID 1, category name Left
# Annotation ID 115: mean depth 55.674418604651166, normalized depth 0.2183310533515732, value_metric 4.679288645690836
# Processing annotation ID 116, category ID 3, category name Right
# Annotation ID 116: mean depth 56.018181818181816, normalized depth 0.21967914438502673, value_metric 4.705711229946525
# Processing annotation ID 117, category ID 2, category name Middle
# Annotation ID 117: mean depth 47.47328244274809, normalized depth 0.18616973506960036, value_metric 4.048926807364167
# Processing image ID 50, name frame_000050.png
# Number of annotations for image frame_000050.png: 0
# Processing image ID 51, name frame_000051.png
# Number of annotations for image frame_000051.png: 0
# Processing image ID 52, name frame_000052.png
# Number of annotations for image frame_000052.png: 0
# Processing image ID 53, name frame_000053.png
# Number of annotations for image frame_000053.png: 0
# Processing image ID 54, name frame_000054.png
# Number of annotations for image frame_000054.png: 0
# Processing image ID 55, name frame_000055.png
# Number of annotations for image frame_000055.png: 0
# Processing image ID 56, name frame_000056.png
# Number of annotations for image frame_000056.png: 0
# Processing image ID 57, name frame_000057.png
# Number of annotations for image frame_000057.png: 0
# Processing image ID 58, name frame_000058.png
# Number of annotations for image frame_000058.png: 0
# Processing image ID 59, name frame_000059.png
# Number of annotations for image frame_000059.png: 0
# Processing image ID 60, name frame_000060.png
# Number of annotations for image frame_000060.png: 0
# Processing image ID 61, name frame_000061.png
# Number of annotations for image frame_000061.png: 0
# Processing image ID 62, name frame_000062.png
# Number of annotations for image frame_000062.png: 0
# Processing image ID 63, name frame_000063.png
# Number of annotations for image frame_000063.png: 0
# Processing image ID 64, name frame_000064.png
# Number of annotations for image frame_000064.png: 3
# Processing annotation ID 118, category ID 2, category name Middle
# Annotation ID 118: mean depth 35.68023255813954, normalized depth 0.13992248062015505, value_metric 3.1424806201550393
# Processing annotation ID 119, category ID 1, category name Left
# Annotation ID 119: mean depth 45.22627737226277, normalized depth 0.17735795047946185, value_metric 3.8762158293974522
# Processing annotation ID 120, category ID 3, category name Right
# Annotation ID 120: mean depth 45.035714285714285, normalized depth 0.17661064425770306, value_metric 3.86156862745098
# Processing image ID 65, name frame_000065.png
# Number of annotations for image frame_000065.png: 3
# Processing annotation ID 121, category ID 3, category name Right
# Annotation ID 121: mean depth 42.8, normalized depth 0.16784313725490194, value_metric 3.689725490196078
# Processing annotation ID 122, category ID 1, category name Left
# Annotation ID 122: mean depth 43.35036496350365, normalized depth 0.17000143122942607, value_metric 3.732028052096751
# Processing annotation ID 123, category ID 2, category name Middle
# Annotation ID 123: mean depth 34.38036809815951, normalized depth 0.13482497293395884, value_metric 3.0425694695055934
# Processing image ID 66, name frame_000066.png
# Number of annotations for image frame_000066.png: 3
# Processing annotation ID 124, category ID 2, category name Middle
# Annotation ID 124: mean depth 32.62222222222222, normalized depth 0.12793028322440086, value_metric 2.907433551198257
# Processing annotation ID 125, category ID 1, category name Left
# Annotation ID 125: mean depth 42.0, normalized depth 0.16470588235294117, value_metric 3.6282352941176472
# Processing annotation ID 126, category ID 3, category name Right
# Annotation ID 126: mean depth 41.54347826086956, normalized depth 0.1629156010230179, value_metric 3.5931457800511506
# Processing image ID 67, name frame_000067.png
# Number of annotations for image frame_000067.png: 3
# Processing annotation ID 127, category ID 1, category name Left
# Annotation ID 127: mean depth 39.39855072463768, normalized depth 0.1545041204887752, value_metric 3.428280761579994
# Processing annotation ID 128, category ID 3, category name Right
# Annotation ID 128: mean depth 38.46511627906977, normalized depth 0.150843593251254, value_metric 3.3565344277245783
# Processing annotation ID 129, category ID 2, category name Middle
# Annotation ID 129: mean depth 30.681528662420384, normalized depth 0.12031972024478582, value_metric 2.758266516797802
# Processing image ID 68, name frame_000068.png
# Number of annotations for image frame_000068.png: 3
# Processing annotation ID 130, category ID 3, category name Right
# Annotation ID 130: mean depth 37.60666666666667, normalized depth 0.14747712418300654, value_metric 3.2905516339869285
# Processing annotation ID 131, category ID 1, category name Left
# Annotation ID 131: mean depth 39.02564102564103, normalized depth 0.15304172951231776, value_metric 3.399617898441428
# Processing annotation ID 132, category ID 2, category name Middle
# Annotation ID 132: mean depth 30.193181818181817, normalized depth 0.11840463458110516, value_metric 2.7207308377896613
# Processing image ID 69, name frame_000069.png
# Number of annotations for image frame_000069.png: 3
# Processing annotation ID 133, category ID 3, category name Right
# Annotation ID 133: mean depth 40.376, normalized depth 0.15833725490196077, value_metric 3.503410196078431
# Processing annotation ID 134, category ID 1, category name Left
# Annotation ID 134: mean depth 40.51282051282051, normalized depth 0.15887380593262945, value_metric 3.5139265962795374
# Processing annotation ID 135, category ID 2, category name Middle
# Annotation ID 135: mean depth 31.798850574712645, normalized depth 0.12470137480279468, value_metric 2.8441469461347757
# Processing image ID 70, name frame_000070.png
# Number of annotations for image frame_000070.png: 3
# Processing annotation ID 136, category ID 2, category name Middle
# Annotation ID 136: mean depth 31.126984126984127, normalized depth 0.12206660441954559, value_metric 2.7925054466230934
# Processing annotation ID 137, category ID 1, category name Left
# Annotation ID 137: mean depth 40.031496062992126, normalized depth 0.15698625907055735, value_metric 3.4769306777829243
# Processing annotation ID 138, category ID 3, category name Right
# Annotation ID 138: mean depth 39.7734375, normalized depth 0.15597426470588235, value_metric 3.457095588235294
# Processing image ID 71, name frame_000071.png
# Number of annotations for image frame_000071.png: 3
# Processing annotation ID 139, category ID 2, category name Middle
# Annotation ID 139: mean depth 32.10795454545455, normalized depth 0.12591354723707665, value_metric 2.8679055258467026
# Processing annotation ID 140, category ID 1, category name Left
# Annotation ID 140: mean depth 40.664, normalized depth 0.15946666666666667, value_metric 3.525546666666667
# Processing annotation ID 141, category ID 3, category name Right
# Annotation ID 141: mean depth 40.3515625, normalized depth 0.15824142156862744, value_metric 3.501531862745098
# Processing image ID 72, name frame_000072.png
# Number of annotations for image frame_000072.png: 3
# Processing annotation ID 142, category ID 2, category name Middle
# Annotation ID 142: mean depth 33.36413043478261, normalized depth 0.1308397271952259, value_metric 2.964458653026428
# Processing annotation ID 143, category ID 3, category name Right
# Annotation ID 143: mean depth 41.43055555555556, normalized depth 0.1624727668845316, value_metric 3.58446623093682
# Processing annotation ID 144, category ID 1, category name Left
# Annotation ID 144: mean depth 42.17355371900826, normalized depth 0.16538648517258142, value_metric 3.641575109382596
# Processing image ID 73, name frame_000073.png
# Number of annotations for image frame_000073.png: 3
# Processing annotation ID 145, category ID 1, category name Left
# Annotation ID 145: mean depth 42.78294573643411, normalized depth 0.16777625778993768, value_metric 3.688414652682779
# Processing annotation ID 146, category ID 2, category name Middle
# Annotation ID 146: mean depth 33.94047619047619, normalized depth 0.1330999066293184, value_metric 3.0087581699346404
# Processing annotation ID 147, category ID 3, category name Right
# Annotation ID 147: mean depth 41.371428571428574, normalized depth 0.1622408963585434, value_metric 3.579921568627451
# Processing image ID 74, name frame_000074.png
# Number of annotations for image frame_000074.png: 3
# Processing annotation ID 148, category ID 3, category name Right
# Annotation ID 148: mean depth 42.25547445255474, normalized depth 0.1657077429511951, value_metric 3.6478717618434238
# Processing annotation ID 149, category ID 2, category name Middle
# Annotation ID 149: mean depth 34.32203389830509, normalized depth 0.1345962113659023, value_metric 3.038085742771685
# Processing annotation ID 150, category ID 1, category name Left
# Annotation ID 150: mean depth 42.83695652173913, normalized depth 0.16798806479113385, value_metric 3.6925660699062237
# Processing image ID 75, name frame_000075.png
# Number of annotations for image frame_000075.png: 3
# Processing annotation ID 151, category ID 1, category name Left
# Annotation ID 151: mean depth 38.947916666666664, normalized depth 0.15273692810457515, value_metric 3.393643790849673
# Processing annotation ID 152, category ID 3, category name Right
# Annotation ID 152: mean depth 38.365671641791046, normalized depth 0.1504536142815335, value_metric 3.348890839918057
# Processing annotation ID 153, category ID 2, category name Middle
# Annotation ID 153: mean depth 31.073446327683616, normalized depth 0.12185665226542594, value_metric 2.7883903844023483
# Processing image ID 76, name frame_000076.png
# Number of annotations for image frame_000076.png: 3
# Processing annotation ID 154, category ID 1, category name Left
# Annotation ID 154: mean depth 37.333333333333336, normalized depth 0.14640522875816994, value_metric 3.269542483660131
# Processing annotation ID 155, category ID 3, category name Right
# Annotation ID 155: mean depth 37.082089552238806, normalized depth 0.14541995902838747, value_metric 3.2502311969563946
# Processing annotation ID 156, category ID 2, category name Middle
# Annotation ID 156: mean depth 29.315217391304348, normalized depth 0.1149616368286445, value_metric 2.6532480818414323
# Processing image ID 77, name frame_000077.png
# Number of annotations for image frame_000077.png: 3
# Processing annotation ID 157, category ID 1, category name Left
# Annotation ID 157: mean depth 39.3125, normalized depth 0.15416666666666667, value_metric 3.421666666666667
# Processing annotation ID 158, category ID 3, category name Right
# Annotation ID 158: mean depth 39.486301369863014, normalized depth 0.15484824066612946, value_metric 3.4350255170561375
# Processing annotation ID 159, category ID 2, category name Middle
# Annotation ID 159: mean depth 31.293785310734464, normalized depth 0.1227207267087626, value_metric 2.805326243491747
# Processing image ID 78, name frame_000078.png
# Number of annotations for image frame_000078.png: 3
# Processing annotation ID 160, category ID 3, category name Right
# Annotation ID 160: mean depth 40.357142857142854, normalized depth 0.15826330532212884, value_metric 3.5019607843137255
# Processing annotation ID 161, category ID 2, category name Middle
# Annotation ID 161: mean depth 32.25824175824176, normalized depth 0.12650290885585003, value_metric 2.8794570135746604
# Processing annotation ID 162, category ID 1, category name Left
# Annotation ID 162: mean depth 40.38317757009346, normalized depth 0.15836540223566062, value_metric 3.503961883818948
# Processing image ID 79, name frame_000079.png
# Number of annotations for image frame_000079.png: 3
# Processing annotation ID 163, category ID 2, category name Middle
# Annotation ID 163: mean depth 31.28813559322034, normalized depth 0.12269857095380525, value_metric 2.804891990694583
# Processing annotation ID 164, category ID 3, category name Right
# Annotation ID 164: mean depth 39.304964539007095, normalized depth 0.1541371158392435, value_metric 3.4210874704491725
# Processing annotation ID 165, category ID 1, category name Left
# Annotation ID 165: mean depth 39.86842105263158, normalized depth 0.1563467492260062, value_metric 3.4643962848297214
# Processing image ID 80, name frame_000080.png
# Number of annotations for image frame_000080.png: 3
# Processing annotation ID 166, category ID 1, category name Left
# Annotation ID 166: mean depth 40.29059829059829, normalized depth 0.15800234623764034, value_metric 3.496845986257751
# Processing annotation ID 167, category ID 2, category name Middle
# Annotation ID 167: mean depth 31.94943820224719, normalized depth 0.12529191451861643, value_metric 2.855721524564882
# Processing annotation ID 168, category ID 3, category name Right
# Annotation ID 168: mean depth 40.007462686567166, normalized depth 0.1568920105355575, value_metric 3.4750834064969274
# Processing image ID 81, name frame_000081.png
# Number of annotations for image frame_000081.png: 3
# Processing annotation ID 169, category ID 2, category name Middle
# Annotation ID 169: mean depth 32.654761904761905, normalized depth 0.1280578898225957, value_metric 2.909934640522876
# Processing annotation ID 170, category ID 1, category name Left
# Annotation ID 170: mean depth 41.308411214953274, normalized depth 0.161993769470405, value_metric 3.5750778816199382
# Processing annotation ID 171, category ID 3, category name Right
# Annotation ID 171: mean depth 41.280575539568346, normalized depth 0.16188460995909154, value_metric 3.572938355198194
# Processing image ID 82, name frame_000082.png
# Number of annotations for image frame_000082.png: 3
# Processing annotation ID 172, category ID 2, category name Middle
# Annotation ID 172: mean depth 31.130208333333332, normalized depth 0.12207924836601307, value_metric 2.7927532679738563
# Processing annotation ID 173, category ID 1, category name Left
# Annotation ID 173: mean depth 39.19298245614035, normalized depth 0.15369797041623667, value_metric 3.4124802201582387
# Processing annotation ID 174, category ID 3, category name Right
# Annotation ID 174: mean depth 39.198581560283685, normalized depth 0.153719927687387, value_metric 3.4129105826727852
# Processing image ID 83, name frame_000083.png
# Number of annotations for image frame_000083.png: 3
# Processing annotation ID 175, category ID 1, category name Left
# Annotation ID 175: mean depth 39.6822429906542, normalized depth 0.1556166391790361, value_metric 3.4500861279091075
# Processing annotation ID 176, category ID 3, category name Right
# Annotation ID 176: mean depth 39.38636363636363, normalized depth 0.15445632798573974, value_metric 3.427344028520499
# Processing annotation ID 177, category ID 2, category name Middle
# Annotation ID 177: mean depth 31.336585365853658, normalized depth 0.1228885700621712, value_metric 2.8086159732185556
# Processing image ID 84, name frame_000084.png
# Number of annotations for image frame_000084.png: 3
# Processing annotation ID 178, category ID 2, category name Middle
# Annotation ID 178: mean depth 30.3502538071066, normalized depth 0.11902060316512392, value_metric 2.732803822036429
# Processing annotation ID 179, category ID 3, category name Right
# Annotation ID 179: mean depth 38.0958904109589, normalized depth 0.14939564867042707, value_metric 3.3281547139403704
# Processing annotation ID 180, category ID 1, category name Left
# Annotation ID 180: mean depth 38.43298969072165, normalized depth 0.15071760663028097, value_metric 3.354065089953507
# Processing image ID 85, name frame_000085.png
# Number of annotations for image frame_000085.png: 3
# Processing annotation ID 181, category ID 3, category name Right
# Annotation ID 181: mean depth 36.81884057971015, normalized depth 0.14438761011651038, value_metric 3.2299971582836036
# Processing annotation ID 182, category ID 1, category name Left
# Annotation ID 182: mean depth 37.427083333333336, normalized depth 0.14677287581699347, value_metric 3.2767483660130723
# Processing annotation ID 183, category ID 2, category name Middle
# Annotation ID 183: mean depth 29.331550802139038, normalized depth 0.1150256894201531, value_metric 2.6545035126350007
# Processing image ID 86, name frame_000086.png
# Number of annotations for image frame_000086.png: 3
# Processing annotation ID 184, category ID 3, category name Right
# Annotation ID 184: mean depth 37.37313432835821, normalized depth 0.14656131109160084, value_metric 3.2726016973953764
# Processing annotation ID 185, category ID 1, category name Left
# Annotation ID 185: mean depth 38.09375, normalized depth 0.14938725490196078, value_metric 3.3279901960784315
# Processing annotation ID 186, category ID 2, category name Middle
# Annotation ID 186: mean depth 29.75, normalized depth 0.11666666666666667, value_metric 2.686666666666667
# Processing image ID 87, name frame_000087.png
# Number of annotations for image frame_000087.png: 3
# Processing annotation ID 187, category ID 2, category name Middle
# Annotation ID 187: mean depth 29.247524752475247, normalized depth 0.11469617549990292, value_metric 2.6480450397980975
# Processing annotation ID 188, category ID 1, category name Left
# Annotation ID 188: mean depth 37.09183673469388, normalized depth 0.14545818327330934, value_metric 3.250980392156863
# Processing annotation ID 189, category ID 3, category name Right
# Annotation ID 189: mean depth 36.81212121212121, normalized depth 0.1443612596553773, value_metric 3.229480689245395
# Processing image ID 88, name frame_000088.png
# Number of annotations for image frame_000088.png: 3
# Processing annotation ID 190, category ID 3, category name Right
# Annotation ID 190: mean depth 36.75, normalized depth 0.14411764705882352, value_metric 3.224705882352941
# Processing annotation ID 191, category ID 2, category name Middle
# Annotation ID 191: mean depth 29.365384615384617, normalized depth 0.11515837104072399, value_metric 2.6571040723981905
# Processing annotation ID 192, category ID 1, category name Left
# Annotation ID 192: mean depth 37.56122448979592, normalized depth 0.14729891956782712, value_metric 3.287058823529412
# Processing image ID 89, name frame_000089.png
# Number of annotations for image frame_000089.png: 3
# Processing annotation ID 193, category ID 1, category name Left
# Annotation ID 193: mean depth 40.142857142857146, normalized depth 0.1574229691876751, value_metric 3.485490196078432
# Processing annotation ID 194, category ID 2, category name Middle
# Annotation ID 194: mean depth 31.494791666666668, normalized depth 0.12350898692810458, value_metric 2.82077614379085
# Processing annotation ID 195, category ID 3, category name Right
# Annotation ID 195: mean depth 39.48026315789474, normalized depth 0.15482456140350878, value_metric 3.434561403508772
# Processing image ID 90, name frame_000090.png
# Number of annotations for image frame_000090.png: 3
# Processing annotation ID 196, category ID 3, category name Right
# Annotation ID 196: mean depth 37.79245283018868, normalized depth 0.14820569737328895, value_metric 3.3048316685164636
# Processing annotation ID 197, category ID 1, category name Left
# Annotation ID 197: mean depth 38.0, normalized depth 0.14901960784313725, value_metric 3.32078431372549
# Processing annotation ID 198, category ID 2, category name Middle
# Annotation ID 198: mean depth 29.995049504950494, normalized depth 0.11762764511745291, value_metric 2.705501844302077
# Processing image ID 91, name frame_000091.png
# Number of annotations for image frame_000091.png: 3
# Processing annotation ID 199, category ID 1, category name Left
# Annotation ID 199: mean depth 40.8, normalized depth 0.15999999999999998, value_metric 3.5359999999999996
# Processing annotation ID 200, category ID 3, category name Right
# Annotation ID 200: mean depth 41.13846153846154, normalized depth 0.16132730015082958, value_metric 3.56201508295626
# Processing annotation ID 201, category ID 2, category name Middle
# Annotation ID 201: mean depth 32.91089108910891, normalized depth 0.12906231799650553, value_metric 2.9296214327315084
# Processing image ID 92, name frame_000092.png
# Number of annotations for image frame_000092.png: 3
# Processing annotation ID 202, category ID 2, category name Middle
# Annotation ID 202: mean depth 32.154639175257735, normalized depth 0.126096624216697, value_metric 2.8714938346472616
# Processing annotation ID 203, category ID 3, category name Right
# Annotation ID 203: mean depth 40.83766233766234, normalized depth 0.1601476954418131, value_metric 3.5388948306595367
# Processing annotation ID 204, category ID 1, category name Left
# Annotation ID 204: mean depth 39.79, normalized depth 0.15603921568627452, value_metric 3.4583686274509806
# Processing image ID 93, name frame_000093.png
# Number of annotations for image frame_000093.png: 3
# Processing annotation ID 205, category ID 3, category name Right
# Annotation ID 205: mean depth 41.58490566037736, normalized depth 0.16307806141324455, value_metric 3.596330003699593
# Processing annotation ID 206, category ID 1, category name Left
# Annotation ID 206: mean depth 41.260416666666664, normalized depth 0.16180555555555554, value_metric 3.5713888888888885
# Processing annotation ID 207, category ID 2, category name Middle
# Annotation ID 207: mean depth 33.60476190476191, normalized depth 0.13178338001867415, value_metric 2.9829542483660134
# Processing image ID 94, name frame_000094.png
# Number of annotations for image frame_000094.png: 3
# Processing annotation ID 208, category ID 1, category name Left
# Annotation ID 208: mean depth 43.180851063829785, normalized depth 0.16933667083854817, value_metric 3.7189987484355442
# Processing annotation ID 209, category ID 2, category name Middle
# Annotation ID 209: mean depth 35.03333333333333, normalized depth 0.13738562091503267, value_metric 3.0927581699346405
# Processing annotation ID 210, category ID 3, category name Right
# Annotation ID 210: mean depth 43.25333333333333, normalized depth 0.16962091503267973, value_metric 3.724569934640523
# Processing image ID 95, name frame_000095.png
# Number of annotations for image frame_000095.png: 3
# Processing annotation ID 211, category ID 2, category name Middle
# Annotation ID 211: mean depth 33.40487804878049, normalized depth 0.1309995217599235, value_metric 2.9675906264945007
# Processing annotation ID 212, category ID 1, category name Left
# Annotation ID 212: mean depth 41.11818181818182, normalized depth 0.16124777183600714, value_metric 3.56045632798574
# Processing annotation ID 213, category ID 3, category name Right
# ...
# Processing image ID 113, name frame_000113.png
# Number of annotations for image frame_000113.png: 3
# Processing annotation ID 265, category ID 2, category name Middle
# Annotation ID 265: mean depth 43.50837988826816, normalized depth 0.1706210976010516, value_metric 3.7441735129806113
# Processing annotation ID 266, category ID 3, category name Right
# Annotation ID 266: mean depth 51.91538461538462, normalized depth 0.2035897435897436, value_metric 4.390358974358975
# Processing annotation ID 267, category ID 1, category name Left
# Annotation ID 267: mean depth 54.115107913669064, normalized depth 0.21221610946536887, value_metric 4.55943574552123
# Processing image ID 114, name frame_000114.png
# Number of annotations for image frame_000114.png: 3
# Processing annotation ID 268, category ID 3, category name Right
# Annotation ID 268: mean depth 52.447154471544714, normalized depth 0.20567511557468515, value_metric 4.43123226526383
# Processing annotation ID 269, category ID 2, category name Middle
# Annotation ID 269: mean depth 44.52173913043478, normalized depth 0.17459505541346973, value_metric 3.822063086104007
# Processing annotation ID 270, category ID 1, category name Left
# Annotation ID 270: mean depth 55.42635658914729, normalized depth 0.21735826113391093, value_metric 4.660221918224655
# Processing image ID 115, name frame_000115.png
# Number of annotations for image frame_000115.png: 3
# Processing annotation ID 271, category ID 1, category name Left
# Annotation ID 271: mean depth 54.28030303030303, normalized depth 0.21286393345216875, value_metric 4.572133095662508
# Processing annotation ID 272, category ID 2, category name Middle
# Annotation ID 272: mean depth 45.19767441860465, normalized depth 0.17724578203374372, value_metric 3.874017327861377
# Processing annotation ID 273, category ID 3, category name Right
# Annotation ID 273: mean depth 52.11290322580645, normalized depth 0.20436432637571156, value_metric 4.4055407969639475
# Processing image ID 116, name frame_000116.png
# Number of annotations for image frame_000116.png: 3
# Processing annotation ID 274, category ID 1, category name Left
# Annotation ID 274: mean depth 55.45238095238095, normalized depth 0.21746031746031744, value_metric 4.662222222222223
# Processing annotation ID 275, category ID 3, category name Right
# Annotation ID 275: mean depth 53.983870967741936, normalized depth 0.21170145477545857, value_metric 4.549348513598988
# Processing annotation ID 276, category ID 2, category name Middle
# Annotation ID 276: mean depth 46.005917159763314, normalized depth 0.18041536141083653, value_metric 3.9361410836523962
# Processing image ID 117, name frame_000117.png
# Number of annotations for image frame_000117.png: 3
# Processing annotation ID 277, category ID 1, category name Left
# Annotation ID 277: mean depth 55.68702290076336, normalized depth 0.21838048196377788, value_metric 4.680257446490047
# Processing annotation ID 278, category ID 2, category name Middle
# Annotation ID 278: mean depth 46.50581395348837, normalized depth 0.18237574099407206, value_metric 3.9745645234838123
# Processing annotation ID 279, category ID 3, category name Right
# Annotation ID 279: mean depth 53.951219512195124, normalized depth 0.21157340985174558, value_metric 4.546838833094214
# Processing image ID 118, name frame_000118.png
# Number of annotations for image frame_000118.png: 3
# Processing annotation ID 280, category ID 2, category name Middle
# Annotation ID 280: mean depth 43.98255813953488, normalized depth 0.17248062015503876, value_metric 3.78062015503876
# Processing annotation ID 281, category ID 3, category name Right
# Annotation ID 281: mean depth 51.30508474576271, normalized depth 0.20119641076769693, value_metric 4.3434496510468605
# Processing annotation ID 282, category ID 1, category name Left
# Annotation ID 282: mean depth 51.8014705882353, normalized depth 0.20314302191464823, value_metric 4.381603229527106
# Processing image ID 119, name frame_000119.png
# Number of annotations for image frame_000119.png: 3
# Processing annotation ID 283, category ID 1, category name Left
# Annotation ID 283: mean depth 53.90163934426229, normalized depth 0.21137897782063644, value_metric 4.543027965284475
# Processing annotation ID 284, category ID 2, category name Middle
# Annotation ID 284: mean depth 46.27218934911242, normalized depth 0.18145956607495067, value_metric 3.9566074950690333
# Processing annotation ID 285, category ID 3, category name Right
# Annotation ID 285: mean depth 53.764227642276424, normalized depth 0.21084010840108403, value_metric 4.532466124661248
# Processing image ID 120, name frame_000120.png
# Number of annotations for image frame_000120.png: 3
# Processing annotation ID 286, category ID 1, category name Left
# Annotation ID 286: mean depth 56.120370370370374, normalized depth 0.22007988380537402, value_metric 4.713565722585331
# Processing annotation ID 287, category ID 3, category name Right
# Annotation ID 287: mean depth 56.483870967741936, normalized depth 0.221505376344086, value_metric 4.741505376344087
# Processing annotation ID 288, category ID 2, category name Middle
# Annotation ID 288: mean depth 48.01129943502825, normalized depth 0.18827960562756177, value_metric 4.0902802703002115
# Processing image ID 121, name frame_000121.png
# Number of annotations for image frame_000121.png: 3
# Processing annotation ID 289, category ID 3, category name Right
# Annotation ID 289: mean depth 60.75, normalized depth 0.23823529411764705, value_metric 5.069411764705883
# Processing annotation ID 290, category ID 1, category name Left
# Annotation ID 290: mean depth 61.29565217391304, normalized depth 0.24037510656436487, value_metric 5.111352088661552
# Processing annotation ID 291, category ID 2, category name Middle
# Annotation ID 291: mean depth 52.616279069767444, normalized depth 0.20633834929320566, value_metric 4.444231646146831
# Processing image ID 122, name frame_000122.png
# Number of annotations for image frame_000122.png: 3
# Processing annotation ID 292, category ID 3, category name Right
# Annotation ID 292: mean depth 59.03448275862069, normalized depth 0.2315077755240027, value_metric 4.937552400270453
# Processing annotation ID 293, category ID 1, category name Left
# Annotation ID 293: mean depth 60.36607142857143, normalized depth 0.23672969187675072, value_metric 5.039901960784315
# Processing annotation ID 294, category ID 2, category name Middle
# Annotation ID 294: mean depth 51.4551724137931, normalized depth 0.20178498985801216, value_metric 4.354985801217039
# Processing image ID 123, name frame_000123.png
# Number of annotations for image frame_000123.png: 3
# Processing annotation ID 295, category ID 3, category name Right
# Annotation ID 295: mean depth 59.440298507462686, normalized depth 0.233099209833187, value_metric 4.968744512730466
# Processing annotation ID 296, category ID 1, category name Left
# Annotation ID 296: mean depth 59.76229508196721, normalized depth 0.23436194149791062, value_metric 4.993494053359049
# Processing annotation ID 297, category ID 2, category name Middle
# Annotation ID 297: mean depth 51.541666666666664, normalized depth 0.20212418300653595, value_metric 4.361633986928105
# Processing image ID 124, name frame_000124.png
# Number of annotations for image frame_000124.png: 3
# Processing annotation ID 298, category ID 2, category name Middle
# Annotation ID 298: mean depth 51.52413793103448, normalized depth 0.20205544286680188, value_metric 4.360286680189318
# Processing annotation ID 299, category ID 3, category name Right
# Annotation ID 299: mean depth 60.08411214953271, normalized depth 0.23562396921385376, value_metric 5.018229796591534
# Processing annotation ID 300, category ID 1, category name Left
# Annotation ID 300: mean depth 59.78504672897196, normalized depth 0.23445116364302732, value_metric 4.995242807403336
# Processing image ID 125, name frame_000125.png
# Number of annotations for image frame_000125.png: 3
# Processing annotation ID 301, category ID 3, category name Right
# Annotation ID 301: mean depth 60.152542372881356, normalized depth 0.2358923230309073, value_metric 5.023489531405784
# Processing annotation ID 302, category ID 1, category name Left
# Annotation ID 302: mean depth 59.169642857142854, normalized depth 0.2320378151260504, value_metric 4.9479411764705885
# Processing annotation ID 303, category ID 2, category name Middle
# Annotation ID 303: mean depth 51.484375, normalized depth 0.20189950980392157, value_metric 4.357230392156863
# Processing image ID 126, name frame_000126.png
# Number of annotations for image frame_000126.png: 3
# Processing annotation ID 304, category ID 2, category name Middle
# Annotation ID 304: mean depth 54.80508474576271, normalized depth 0.21492190096377534, value_metric 4.612469258889997
# Processing annotation ID 305, category ID 3, category name Right
# Annotation ID 305: mean depth 62.88785046728972, normalized depth 0.24661902144035183, value_metric 5.233732820230896
# Processing annotation ID 306, category ID 1, category name Left
# Annotation ID 306: mean depth 63.788990825688074, normalized depth 0.25015290519877675, value_metric 5.302996941896025
# Processing image ID 127, name frame_000127.png
# Number of annotations for image frame_000127.png: 3
# Processing annotation ID 307, category ID 3, category name Right
# Annotation ID 307: mean depth 67.54205607476635, normalized depth 0.2648708081363386, value_metric 5.591467839472237
# Processing annotation ID 308, category ID 2, category name Middle
# Annotation ID 308: mean depth 58.45528455284553, normalized depth 0.22923641001115894, value_metric 4.893033636218716
# Processing annotation ID 309, category ID 1, category name Left
# Annotation ID 309: mean depth 67.8203125, normalized depth 0.2659620098039216, value_metric 5.612855392156864
# Processing image ID 128, name frame_000128.png
# Number of annotations for image frame_000128.png: 3
# Processing annotation ID 310, category ID 1, category name Left
# Annotation ID 310: mean depth 61.88135593220339, normalized depth 0.24267198404785645, value_metric 5.156370887337987
# Processing annotation ID 311, category ID 3, category name Right
# Annotation ID 311: mean depth 61.75925925925926, normalized depth 0.2421931735657226, value_metric 5.146986201888163
# Processing annotation ID 312, category ID 2, category name Middle
# Annotation ID 312: mean depth 54.776, normalized depth 0.21480784313725493, value_metric 4.610233725490197
# Processing image ID 129, name frame_000129.png
# Number of annotations for image frame_000129.png: 3
# Processing annotation ID 313, category ID 2, category name Middle
# Annotation ID 313: mean depth 54.45614035087719, normalized depth 0.2135534915720674, value_metric 4.585648434812522
# Processing annotation ID 314, category ID 1, category name Left
# Annotation ID 314: mean depth 60.61616161616162, normalized depth 0.23771043771043773, value_metric 5.05912457912458
# Processing annotation ID 315, category ID 3, category name Right
# Annotation ID 315: mean depth 61.47663551401869, normalized depth 0.24108484515301445, value_metric 5.125262964999084
# Processing image ID 130, name frame_000130.png
# Number of annotations for image frame_000130.png: 3
# Processing annotation ID 316, category ID 2, category name Middle
# Annotation ID 316: mean depth 58.604651162790695, normalized depth 0.22982216142270862, value_metric 4.90451436388509
# Processing annotation ID 317, category ID 3, category name Right
# Annotation ID 317: mean depth 66.74038461538461, normalized depth 0.2617269984917044, value_metric 5.529849170437407
# Processing annotation ID 318, category ID 1, category name Left
# Annotation ID 318: mean depth 65.93333333333334, normalized depth 0.258562091503268, value_metric 5.467816993464053
# Processing image ID 131, name frame_000131.png
# Number of annotations for image frame_000131.png: 0
# Processing image ID 132, name frame_000132.png
# Number of annotations for image frame_000132.png: 0
# Processing image ID 133, name frame_000133.png
# Number of annotations for image frame_000133.png: 0
# Processing image ID 134, name frame_000134.png
# Number of annotations for image frame_000134.png: 0
# Processing image ID 135, name frame_000135.png
# Number of annotations for image frame_000135.png: 0
# Processing image ID 136, name frame_000136.png
# Number of annotations for image frame_000136.png: 0
# Processing image ID 137, name frame_000137.png
# Number of annotations for image frame_000137.png: 0
# Processing image ID 138, name frame_000138.png
# Number of annotations for image frame_000138.png: 0
# Processing image ID 139, name frame_000139.png
# Number of annotations for image frame_000139.png: 0
# Processing image ID 140, name frame_000140.png
# Number of annotations for image frame_000140.png: 0
# Processing image ID 141, name frame_000141.png
# Number of annotations for image frame_000141.png: 0
# Processing image ID 142, name frame_000142.png
# Number of annotations for image frame_000142.png: 0
# Processing image ID 143, name frame_000143.png
# Number of annotations for image frame_000143.png: 0
# Processing image ID 144, name frame_000144.png
# Number of annotations for image frame_000144.png: 0
# Processing image ID 145, name frame_000145.png
# Number of annotations for image frame_000145.png: 0
# Processing image ID 146, name frame_000146.png
# Number of annotations for image frame_000146.png: 0
# Processing image ID 147, name frame_000147.png
# Number of annotations for image frame_000147.png: 0
# Processing image ID 148, name frame_000148.png
# Number of annotations for image frame_000148.png: 0
# Processing image ID 149, name frame_000149.png
# Number of annotations for image frame_000149.png: 0
# Processing image ID 150, name frame_000150.png
# Number of annotations for image frame_000150.png: 0
# Processing image ID 151, name frame_000151.png
# Number of annotations for image frame_000151.png: 0
# Processing image ID 152, name frame_000152.png
# Number of annotations for image frame_000152.png: 0
# Processing image ID 153, name frame_000153.png
# Number of annotations for image frame_000153.png: 0
# Processing image ID 154, name frame_000154.png
# Number of annotations for image frame_000154.png: 0
# Processing image ID 155, name frame_000155.png
# Number of annotations for image frame_000155.png: 0
# Processing image ID 156, name frame_000156.png
# Number of annotations for image frame_000156.png: 0
# Processing image ID 157, name frame_000157.png
# Number of annotations for image frame_000157.png: 0
# Processing image ID 158, name frame_000158.png
# Number of annotations for image frame_000158.png: 0
# Processing image ID 159, name frame_000159.png
# Number of annotations for image frame_000159.png: 0
# Processing image ID 160, name frame_000160.png
# Number of annotations for image frame_000160.png: 0
# Processing image ID 161, name frame_000161.png
# Number of annotations for image frame_000161.png: 0
# Processing image ID 162, name frame_000162.png
# Number of annotations for image frame_000162.png: 0
# Processing image ID 163, name frame_000163.png
# Number of annotations for image frame_000163.png: 0
# Processing image ID 164, name frame_000164.png
# Number of annotations for image frame_000164.png: 0
# Processing image ID 165, name frame_000165.png
# Number of annotations for image frame_000165.png: 0
# Processing image ID 166, name frame_000166.png
# Number of annotations for image frame_000166.png: 0
# Results DataFrame:
#          image_name  image_id  annotation_id  frame  category_id  \
# 0  frame_000001.png         1              1      1            2
# 1  frame_000001.png         1              2      1            1
# 2  frame_000001.png         1              3      1            3
# 3  frame_000002.png         2              4      2            2
# 4  frame_000002.png         2              5      2            1
#
#   category_name  normalized_depth  z-min  z-max  value_metric
# 0        Middle          0.242291    0.4   20.0      5.148912
# 1          Left          0.278561    0.4   20.0      5.859789
# 2         Right          0.280764    0.4   20.0      5.902983
# 3        Middle          0.246797    0.4   20.0      5.237229
# 4          Left          0.283098    0.4   20.0      5.948722
