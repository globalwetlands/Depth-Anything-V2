# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = '../data/deigo/results_stingray_vid.csv'

# %%
# Read the CSV data
df = pd.read_csv(csv_path)
df.head()
# Out:
#                      depth_map_file           annotation_image  annotation_id  \
# 0  stingray_frame_000001_pred04.png  stingray_frame_000001.png             48
# 1  stingray_frame_000001_pred04.png  stingray_frame_000001.png             49
# 2  stingray_frame_000002_pred04.png  stingray_frame_000001.png             48
# 3  stingray_frame_000002_pred04.png  stingray_frame_000001.png             49
# 4  stingray_frame_000003_pred04.png  stingray_frame_000001.png             48
#
#    category_id  category_name  normalized_depth  z-min  z-max  value_metric
# 0            5             90          0.806614    0.4   20.0     16.209628
# 1            4             80          0.833003    0.4   20.0     16.726862
# 2            5             90          0.876345    0.4   20.0     17.576371
# 3            4             80          0.961148    0.4   20.0     19.238504
# 4            5             90          0.866863    0.4   20.0     17.390523

# %%
print(df.columns.tolist())
# Out:
# ['depth_map_file', 'annotation_image', 'annotation_id', 'category_id', 'category_name', 'normalized_depth', 'z-min', 'z-max', 'value_metric']

# %%
# Display the data
print(df[['category_name', 'normalized_depth']])
# Out:
#      category_name  normalized_depth
# 0               90          0.806614
# 1               80          0.833003
# 2               90          0.876345
# 3               80          0.961148
# 4               90          0.866863
# ..             ...               ...
# 365             90          0.868354
# 366             80          0.905928
# 367             90          0.845416
# 368             80          0.943303
# 369             90          0.873511
#
# [370 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='category_name', y='normalized_depth', data=df)
plt.title('Normalized Depth by Category')
plt.xlabel('Category Name')
plt.ylabel('Normalized Depth')
plt.show()

# %%
# Calculate mean values for each category
means = df.groupby('category_name')['normalized_depth'].mean()

# Print the means
print("Mean Normalized Depth by Category:")
print(means)
# Out:
# Mean Normalized Depth by Category:
# category_name
# 80    0.921136
# 90    0.841058
# Name: normalized_depth, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(x='category_name', y='normalized_depth', data=df, jitter=True)
plt.title('Normalized Depth by Category')
plt.xlabel('Category Name')
plt.ylabel('Normalized Depth')
plt.show()
