# %%
import os
import numpy as np
import pandas as pd
import cv2
from pycocotools.coco import COCO
from pycocotools import mask as maskUtils

# %%
# Define directories
image_directory = '../data/deigo/annotate-frames'  # Original Images
depth_map_directory = '../data/deigo/depth-maps/annotate-frames-dmap'  # Depth Map Images
json_file = '../data/deigo/diego-pipe-annotations/annotations/instances_default.json'  # JSON file

# Update the path to save results
results_csv_path = '../data/deigo/diego.csv'

# %%
# Load the COCO annotations
coco = COCO(json_file)

# Create a mapping from category_id to category_name
cats = coco.loadCats(coco.getCatIds())
category_mapping = {cat['id']: cat['name'] for cat in cats}
print("Category mapping:")
print(category_mapping)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Category mapping:
# {1: '50', 2: '60', 3: '70', 4: '80', 5: '90'}

# %%
def load_depth_map(img_name):
    # Construct the depth map filename
    depth_map_filename = f"{img_name}_pred04.png"  # img_name without extension + '_pred04.png'
    depth_map_path = os.path.join(depth_map_directory, depth_map_filename)
    
    # Check if the depth map exists
    if not os.path.exists(depth_map_path):
        print(f"Depth map for image {img_name} not found at {depth_map_path}.")
        return None
    
    # Load the depth map image
    depth_map = cv2.imread(depth_map_path, cv2.IMREAD_UNCHANGED)
    if depth_map is None:
        print(f"Failed to load depth map for image {img_name}.")
        return None
    
    # Normalize the depth map if necessary (adjust based on your depth map format)
    if depth_map.dtype == np.uint8:
        # 8-bit depth map
        depth_map_normalized = depth_map / 255.0
    elif depth_map.dtype == np.uint16:
        # 16-bit depth map
        depth_map_normalized = depth_map / 65535.0
    else:
        # If depth map is already in float format between 0 and 1
        depth_map_normalized = depth_map

    return depth_map_normalized

# %%
def create_mask_from_annotation(ann, img_height, img_width):
    segmentation = ann['segmentation']
    
    if isinstance(segmentation, list):  # Polygon format
        mask = np.zeros((img_height, img_width), dtype=np.uint8)
        # Convert polygons to a mask
        for poly in segmentation:
            poly = np.array(poly).reshape((-1, 2))  # Reshape to (N, 2)
            cv2.fillPoly(mask, [np.int32(poly)], 1)  # Fill the polygon with 1's

    elif isinstance(segmentation, dict) and 'counts' in segmentation:  # RLE format
        rle = segmentation
        if isinstance(rle['counts'], list):  # Uncompressed RLE
            rle = maskUtils.frPyObjects([rle], img_height, img_width)
        mask = maskUtils.decode(rle)  # Decode RLE to binary mask

    else:
        mask = None  # Segmentation format not recognized

    return mask

# %%
# List to store results
results = []

# Get all image IDs
image_ids = coco.getImgIds()
print(f"Total number of images: {len(image_ids)}")
# Out:
# Total number of images: 17

# %%
# Process each image
for img_id in image_ids:
    # Load image information
    img_info = coco.loadImgs(img_id)[0]
    img_name_with_ext = img_info['file_name']  # e.g., '1.png'
    img_name = os.path.splitext(img_name_with_ext)[0]  # e.g., '1'
    img_height = img_info['height']
    img_width = img_info['width']
    
    print(f"Processing image ID {img_id}, name {img_name_with_ext}")

    # Load depth map
    depth_map = load_depth_map(img_name)
    if depth_map is None:
        print(f"Skipping image {img_name_with_ext} due to missing depth map.")
        continue  # Skip if depth map is not available

    # Get annotation IDs for the image
    ann_ids = coco.getAnnIds(imgIds=img_id)
    anns = coco.loadAnns(ann_ids)
    
    print(f"Number of annotations for image {img_name_with_ext}: {len(anns)}")
    
    # Process each annotation
    for ann in anns:
        annotation_id = ann['id']
        category_id = ann['category_id']
        category_name = category_mapping.get(category_id, "Unknown")
        print(f"Processing annotation ID {annotation_id}, category ID {category_id}, category name {category_name}")
        
        # Create mask for the annotation
        mask = create_mask_from_annotation(ann, img_height, img_width)
        if mask is None:
            print(f"Failed to create mask for annotation {annotation_id}")
            continue  # Skip if mask couldn't be created
        
        # Apply the mask to the depth map to extract depth values
        depth_values = depth_map[mask == 1]
        mean_depth = depth_values.mean() if depth_values.size > 0 else 0
        normalized_depth = mean_depth  # Depth map is already normalized between 0 and 1
        
        # Convert normalized depth to metric depth
        zmin = 0.4  # Minimum depth in meters (adjust if necessary)
        zmax = 20.0  # Maximum depth in meters (adjust if necessary)
        value_metric = (normalized_depth * (zmax - zmin)) + zmin
        
        print(f"Annotation ID {annotation_id}: mean depth {mean_depth}, normalized depth {normalized_depth}, value_metric {value_metric}")
        
        # Append the result to the list
        results.append({
            'image_name': img_name_with_ext,
            'image_id': img_id,
            'annotation_id': annotation_id,
            'category_id': category_id,
            'category_name': category_name,
            'normalized_depth': normalized_depth,
            'z-min': zmin,
            'z-max': zmax,
            'value_metric': value_metric
        })

# Create a DataFrame from the results
results_df = pd.DataFrame(results)

# Display the DataFrame
print("Results DataFrame:")
print(results_df.head())

# Save the results to a CSV file
results_df.to_csv(results_csv_path, index=False)
print(f"Results saved to {results_csv_path}")
# Out:
# Processing image ID 1, name 1.png
# Number of annotations for image 1.png: 3
# Processing annotation ID 1, category ID 2, category name 60
# Annotation ID 1: mean depth 0.22650808957462773, normalized depth 0.22650808957462773, value_metric 4.8395585556627045
# Processing annotation ID 2, category ID 1, category name 50
# Annotation ID 2: mean depth 0.1950980392156863, normalized depth 0.1950980392156863, value_metric 4.223921568627452
# Processing annotation ID 3, category ID 5, category name 90
# Annotation ID 3: mean depth 0.281126938437441, normalized depth 0.281126938437441, value_metric 5.910087993373844
# Processing image ID 2, name 10.png
# Number of annotations for image 10.png: 3
# Processing annotation ID 4, category ID 2, category name 60
# Annotation ID 4: mean depth 0.6445383117786121, normalized depth 0.6445383117786121, value_metric 13.032950910860798
# Processing annotation ID 5, category ID 5, category name 90
# Annotation ID 5: mean depth 0.7180322323698537, normalized depth 0.7180322323698537, value_metric 14.473431754449134
# Processing annotation ID 6, category ID 1, category name 50
# Annotation ID 6: mean depth 0.5673258556870203, normalized depth 0.5673258556870203, value_metric 11.5195867714656
# Processing image ID 3, name 2.png
# Number of annotations for image 2.png: 2
# Processing annotation ID 7, category ID 5, category name 90
# Annotation ID 7: mean depth 0.8154624289803065, normalized depth 0.8154624289803065, value_metric 16.38306360801401
# Processing annotation ID 8, category ID 1, category name 50
# Annotation ID 8: mean depth 0.7946956394498097, normalized depth 0.7946956394498097, value_metric 15.976034533216271
# Processing image ID 4, name 3.png
# Number of annotations for image 3.png: 3
# Processing annotation ID 9, category ID 2, category name 60
# Annotation ID 9: mean depth 0.6008212709167436, normalized depth 0.6008212709167436, value_metric 12.176096909968177
# Processing annotation ID 10, category ID 5, category name 90
# Annotation ID 10: mean depth 0.6696396633639466, normalized depth 0.6696396633639466, value_metric 13.524937401933355
# Processing annotation ID 11, category ID 1, category name 50
# Annotation ID 11: mean depth 0.5226485775032904, normalized depth 0.5226485775032904, value_metric 10.643912119064494
# Processing image ID 5, name 4.png
# Number of annotations for image 4.png: 3
# Processing annotation ID 12, category ID 5, category name 90
# Annotation ID 12: mean depth 0.3867442838727186, normalized depth 0.3867442838727186, value_metric 7.980187963905285
# Processing annotation ID 13, category ID 2, category name 60
# Annotation ID 13: mean depth 0.29288525582803515, normalized depth 0.29288525582803515, value_metric 6.14055101422949
# Processing annotation ID 14, category ID 1, category name 50
# Annotation ID 14: mean depth 0.18495637277092822, normalized depth 0.18495637277092822, value_metric 4.025144906310193
# Processing image ID 6, name 5.png
# Number of annotations for image 5.png: 3
# Processing annotation ID 15, category ID 5, category name 90
# Annotation ID 15: mean depth 0.3945619538137836, normalized depth 0.3945619538137836, value_metric 8.133414294750159
# Processing annotation ID 16, category ID 2, category name 60
# Annotation ID 16: mean depth 0.3002311969563945, normalized depth 0.3002311969563945, value_metric 6.284531460345333
# Processing annotation ID 17, category ID 1, category name 50
# Annotation ID 17: mean depth 0.19001747040279526, normalized depth 0.19001747040279526, value_metric 4.124342419894788
# Processing image ID 7, name 6.png
# Number of annotations for image 6.png: 3
# Processing annotation ID 18, category ID 5, category name 90
# Annotation ID 18: mean depth 0.9659106105024945, normalized depth 0.9659106105024945, value_metric 19.33184796584889
# Processing annotation ID 19, category ID 1, category name 50
# Annotation ID 19: mean depth 0.871879458102944, normalized depth 0.871879458102944, value_metric 17.488837378817703
# Processing annotation ID 20, category ID 2, category name 60
# Annotation ID 20: mean depth 0.9413417743779126, normalized depth 0.9413417743779126, value_metric 18.850298777807087
# Processing image ID 8, name 7.png
# Number of annotations for image 7.png: 3
# Processing annotation ID 21, category ID 1, category name 50
# Annotation ID 21: mean depth 0.8480865576422787, normalized depth 0.8480865576422787, value_metric 17.02249652978866
# Processing annotation ID 22, category ID 5, category name 90
# Annotation ID 22: mean depth 0.8829007312998148, normalized depth 0.8829007312998148, value_metric 17.70485433347637
# Processing annotation ID 23, category ID 2, category name 60
# Annotation ID 23: mean depth 0.8880136890235352, normalized depth 0.8880136890235352, value_metric 17.80506830486129
# Processing image ID 9, name 8.png
# Number of annotations for image 8.png: 3
# Processing annotation ID 24, category ID 5, category name 90
# Annotation ID 24: mean depth 0.8436981993054373, normalized depth 0.8436981993054373, value_metric 16.936484706386572
# Processing annotation ID 25, category ID 1, category name 50
# Annotation ID 25: mean depth 0.8000194779898715, normalized depth 0.8000194779898715, value_metric 16.08038176860148
# Processing annotation ID 26, category ID 2, category name 60
# Annotation ID 26: mean depth 0.8387031709817147, normalized depth 0.8387031709817147, value_metric 16.838582151241607
# Processing image ID 10, name 9.png
# Number of annotations for image 9.png: 3
# Processing annotation ID 27, category ID 1, category name 50
# Annotation ID 27: mean depth 0.617438634221461, normalized depth 0.617438634221461, value_metric 12.501797230740635
# Processing annotation ID 28, category ID 2, category name 60
# Annotation ID 28: mean depth 0.6424331965344278, normalized depth 0.6424331965344278, value_metric 12.991690652074785
# Processing annotation ID 29, category ID 5, category name 90
# Annotation ID 29: mean depth 0.6382541225512088, normalized depth 0.6382541225512088, value_metric 12.909780802003695
# Processing image ID 11, name Daytime.png
# Number of annotations for image Daytime.png: 5
# Processing annotation ID 30, category ID 5, category name 90
# Annotation ID 30: mean depth 0.20369456807335515, normalized depth 0.20369456807335515, value_metric 4.392413534237761
# Processing annotation ID 31, category ID 3, category name 70
# Annotation ID 31: mean depth 0.15057547424476672, normalized depth 0.15057547424476672, value_metric 3.3512792951974277
# Processing annotation ID 32, category ID 2, category name 60
# Annotation ID 32: mean depth 0.12601543784934788, normalized depth 0.12601543784934788, value_metric 2.8699025818472186
# Processing annotation ID 33, category ID 1, category name 50
# Annotation ID 33: mean depth 0.10082232695254167, normalized depth 0.10082232695254167, value_metric 2.376117608269817
# Processing annotation ID 34, category ID 4, category name 80
# Annotation ID 34: mean depth 0.1665556788753237, normalized depth 0.1665556788753237, value_metric 3.664491305956344
# Processing image ID 12, name bream_oyster_frame_000001.png
# Number of annotations for image bream_oyster_frame_000001.png: 5
# Processing annotation ID 35, category ID 4, category name 80
# Annotation ID 35: mean depth 0.16872008645978076, normalized depth 0.16872008645978076, value_metric 3.706913694611703
# Processing annotation ID 36, category ID 3, category name 70
# Annotation ID 36: mean depth 0.16469980240158077, normalized depth 0.16469980240158077, value_metric 3.6281161270709834
# Processing annotation ID 37, category ID 5, category name 90
# Annotation ID 37: mean depth 0.20801279453638719, normalized depth 0.20801279453638719, value_metric 4.47705077291319
# Processing annotation ID 38, category ID 1, category name 50
# Annotation ID 38: mean depth 0.10898823529411766, normalized depth 0.10898823529411766, value_metric 2.5361694117647064
# Processing annotation ID 39, category ID 2, category name 60
# Annotation ID 39: mean depth 0.13600034137702957, normalized depth 0.13600034137702957, value_metric 3.06560669098978
# Processing image ID 13, name puffer_oyster_frame_000001.png
# Number of annotations for image puffer_oyster_frame_000001.png: 3
# Processing annotation ID 40, category ID 5, category name 90
# Annotation ID 40: mean depth 0.9663181689742866, normalized depth 0.9663181689742866, value_metric 19.339836111896016
# Processing annotation ID 41, category ID 2, category name 60
# Annotation ID 41: mean depth 0.9152312986443107, normalized depth 0.9152312986443107, value_metric 18.33853345342849
# Processing annotation ID 42, category ID 1, category name 50
# Annotation ID 42: mean depth 0.8423933775844968, normalized depth 0.8423933775844968, value_metric 16.910910200656136
# Processing image ID 14, name scat_oyster_frame_000001.png
# Number of annotations for image scat_oyster_frame_000001.png: 5
# Processing annotation ID 43, category ID 4, category name 80
# Annotation ID 43: mean depth 0.5697911684999203, normalized depth 0.5697911684999203, value_metric 11.56790690259844
# Processing annotation ID 44, category ID 3, category name 70
# Annotation ID 44: mean depth 0.5036805180787911, normalized depth 0.5036805180787911, value_metric 10.272138154344306
# Processing annotation ID 45, category ID 2, category name 60
# Annotation ID 45: mean depth 0.4167673257770056, normalized depth 0.4167673257770056, value_metric 8.568639585229311
# Processing annotation ID 46, category ID 5, category name 90
# Annotation ID 46: mean depth 0.586669962102488, normalized depth 0.586669962102488, value_metric 11.898731257208766
# Processing annotation ID 47, category ID 1, category name 50
# Annotation ID 47: mean depth 0.30435237099686396, normalized depth 0.30435237099686396, value_metric 6.365306471538535
# Processing image ID 15, name stingray_frame_000001.png
# Number of annotations for image stingray_frame_000001.png: 2
# Processing annotation ID 48, category ID 5, category name 90
# Annotation ID 48: mean depth 0.8066136663482099, normalized depth 0.8066136663482099, value_metric 16.209627860424913
# Processing annotation ID 49, category ID 4, category name 80
# Annotation ID 49: mean depth 0.8330031669024996, normalized depth 0.8330031669024996, value_metric 16.72686207128899
# Processing image ID 16, name stingray_frame_000002.png
# Number of annotations for image stingray_frame_000002.png: 2
# Processing annotation ID 50, category ID 5, category name 90
# Annotation ID 50: mean depth 0.8613552700773798, normalized depth 0.8613552700773798, value_metric 17.282563293516642
# Processing annotation ID 51, category ID 4, category name 80
# Annotation ID 51: mean depth 0.9568627450980391, normalized depth 0.9568627450980391, value_metric 19.154509803921567
# Processing image ID 17, name stingray_frame_000003.png
# Number of annotations for image stingray_frame_000003.png: 2
# Processing annotation ID 52, category ID 4, category name 80
# Annotation ID 52: mean depth 0.9433031674208145, normalized depth 0.9433031674208145, value_metric 18.888742081447965
# Processing annotation ID 53, category ID 5, category name 90
# Annotation ID 53: mean depth 0.8735106988853635, normalized depth 0.8735106988853635, value_metric 17.520809698153123
# Results DataFrame:
#   image_name  image_id  annotation_id  category_id category_name  \
# 0      1.png         1              1            2            60
# 1      1.png         1              2            1            50
# 2      1.png         1              3            5            90
# 3     10.png         2              4            2            60
# 4     10.png         2              5            5            90
#
#    normalized_depth  z-min  z-max  value_metric
# 0          0.226508    0.4   20.0      4.839559
# 1          0.195098    0.4   20.0      4.223922
# 2          0.281127    0.4   20.0      5.910088
# 3          0.644538    0.4   20.0     13.032951
# 4          0.718032    0.4   20.0     14.473432
# Results saved to ../data/deigo/diego.csv
